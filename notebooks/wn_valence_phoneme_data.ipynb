# %%
import pandas as pd
import numpy as np

from tqdm import tqdm
from pandarallel import pandarallel
import json
pandarallel.initialize(progress_bar=True)
# Out:
# INFO: Pandarallel will run on 10 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.

# %%
import matplotlib.pyplot as plt  # To visualize
import json
from collections import Counter, defaultdict

from sklearn.linear_model import LinearRegression
import seaborn as sns
# %matplotlib inline
pd.set_option('display.max_columns', 200)

# %% [markdown]
# # WN COLEX

# %%
df = pd.read_csv("../data/colex/wn_colex/wn_synsets.csv", sep="\t")

# %%
df["C1"]= df["SYNSET1"].str.split("#").str[0]
df["C2"]= df["SYNSET2"].str.split("#").str[0]

# %%
len(df)
# Out:
# 6177223

# %% [markdown]
# ### get only the top senses from synset.

# %%
df = df[df["SYNSET1"].str.contains("#1")]
df = df[df["SYNSET2"].str.contains("#1")]

# %%
len(df)
# Out:
# 2024695

# %%
df["diff"]=df["C1"]!=df["C2"]

# %%
df = df[df["diff"]==True] # real colex

# %%
len(df)
# Out:
# 1980472

# %%
def get_lower(x):
    try:
        return x.lower()
    except Exception:
        return x

# %%
df["lang"]=df["LANG"].apply(get_lower)

# %%
# df.to_csv("../data/colex/colex_wn#1.csv", index=False)

# %%
len(df)
# Out:
# 1980472

# %% [markdown]
# # Merge df with VALENCE data

# %%
df["C1"]=df["C1"].str.lower()
df["C2"]=df["C2"].str.lower()

# %%
df[df["C1"]=="apple_juice"]
# Out:
#            SENSE_LEMMA LANG          SYNSET1           SYNSET2           C1
# 1492887     äppeljuice   SV  apple_juice#n#1         juice#n#1  apple_juice  \
# 3294938       appelsap   NL  apple_juice#n#1  mulled_cider#n#1  apple_juice
# 3294940            苹果汁   ZH  apple_juice#n#1    applesauce#n#1  apple_juice
# 3294941            苹果汁   ZH  apple_juice#n#1  mulled_cider#n#1  apple_juice
# 4460920     jabukovača   HR  apple_juice#n#1         cider#n#1  apple_juice
# 4460921     jabukovača   HR  apple_juice#n#1     applejack#n#1  apple_juice
# 4460922  сок_од_јабуке   SR  apple_juice#n#1         cider#n#1  apple_juice
# 4460925    عصير_التفاح   AR  apple_juice#n#1         cider#n#1  apple_juice
# 4460926    عصير_التفاح   AR  apple_juice#n#1    applesauce#n#1  apple_juice
# 4460927  sok_od_jabuke   HR  apple_juice#n#1         cider#n#1  apple_juice
# 4460928       eplasafi   IS  apple_juice#n#1         cider#n#1  apple_juice
# 4460931   jablčný_mušt   SK  apple_juice#n#1         cider#n#1  apple_juice
# 4460932  jablečný_mošt   CS  apple_juice#n#1         cider#n#1  apple_juice
# 5952032  jablečný_džus   CS  apple_juice#n#1    applesauce#n#1  apple_juice
# 5952033  jablkový_džús   SK  apple_juice#n#1    applesauce#n#1  apple_juice
# 5952034    suc_de_mere   RO  apple_juice#n#1    applesauce#n#1  apple_juice
# 5952035      sucdemere   RO  apple_juice#n#1    applesauce#n#1  apple_juice
#
#                    C2  diff lang
# 1492887         juice  True   sv
# 3294938  mulled_cider  True   nl
# 3294940    applesauce  True   zh
# 3294941  mulled_cider  True   zh
# 4460920         cider  True   hr
# 4460921     applejack  True   hr
# 4460922         cider  True   sr
# 4460925         cider  True   ar
# 4460926    applesauce  True   ar
# 4460927         cider  True   hr
# 4460928         cider  True   is
# 4460931         cider  True   sk
# 4460932         cider  True   cs
# 5952032    applesauce  True   cs
# 5952033    applesauce  True   sk
# 5952034    applesauce  True   ro
# 5952035    applesauce  True   ro

# %%
df_wkb = pd.read_csv("../data/colex_affective/datasets/WKB.csv")

# %%
df_wkb["len"]=df_wkb["Word"].str.split().str.len()

# %%
df_wkb["len"].value_counts()
# Out:
# len
# 1.0    13812
# 2.0       98
# 3.0        4
# Name: count, dtype: int64

# %%
df_wkb["lemma"]=df_wkb["Word"].str.replace(" ", "_").str.lower()

# %%
wkb_cols = [ "lemma","V.Mean.Sum", "V.SD.Sum", "V.Rat.Sum", "A.Mean.Sum", "A.SD.Sum", "A.Rat.Sum", "D.Mean.Sum", "D.SD.Sum", "D.Rat.Sum"]

# %%
df_wkb  = df_wkb[wkb_cols]

# %%
df_wkb[df_wkb["lemma"]=="jail"]
# Out:
#      lemma  V.Mean.Sum  V.SD.Sum  V.Rat.Sum  A.Mean.Sum  A.SD.Sum  A.Rat.Sum
# 6650  jail        1.91      1.44        870        4.47       2.5         38  \
#
#       D.Mean.Sum  D.SD.Sum  D.Rat.Sum
# 6650        3.91      2.91         23

# %%
len(df_wkb)
# Out:
# 13915

# %%
len(df)
# Out:
# 1980472

# %%
df_merge = pd.merge(df, df_wkb, how="left", left_on="C1",right_on="lemma")

# %%
renames_c1= {col:"C1."+col for col in wkb_cols}
renames_c2= {col:"C2."+col for col in wkb_cols}

# %%
df_merge.rename(columns = renames_c1, inplace=True)

# %%
df_merge = pd.merge(df_merge, df_wkb, how="left", left_on="C2",right_on="lemma")

# %%
df_merge.rename(columns = renames_c2, inplace=True)

# %%
# df_merge.dropna(subset=["C1.lemma", "C2.lemma"], inplace=True)

# %%
df_merge
# Out:
#                      SENSE_LEMMA LANG             SYNSET1          SYNSET2
# 0        tropidoclonion_lineatum   BG  Tropidoclonion#n#1  lined_snake#n#1  \
# 1        tropidoclonion_lineatum   RU  Tropidoclonion#n#1  lined_snake#n#1
# 2        tropidoclonion_lineatum   UK  Tropidoclonion#n#1  lined_snake#n#1
# 3        tropidoclonion_lineatum   GA  Tropidoclonion#n#1  lined_snake#n#1
# 4        tropidoclonion_lineatum   RO  Tropidoclonion#n#1  lined_snake#n#1
# ...                          ...  ...                 ...              ...
# 1981301                   menuil   MS            jack#v#1          pry#v#1
# 1981302                   menuas   MS            jack#v#1          pry#v#1
# 1981303                   menuil   ID            jack#v#1          pry#v#1
# 1981304                   menuas   ID            jack#v#1          pry#v#1
# 1981305               mengungkit   ID            jack#v#1          pry#v#1
#
#                      C1           C2  diff lang C1.lemma  C1.V.Mean.Sum
# 0        tropidoclonion  lined_snake  True   bg      NaN            NaN  \
# 1        tropidoclonion  lined_snake  True   ru      NaN            NaN
# 2        tropidoclonion  lined_snake  True   uk      NaN            NaN
# 3        tropidoclonion  lined_snake  True   ga      NaN            NaN
# 4        tropidoclonion  lined_snake  True   ro      NaN            NaN
# ...                 ...          ...   ...  ...      ...            ...
# 1981301            jack          pry  True   ms      NaN            NaN
# 1981302            jack          pry  True   ms      NaN            NaN
# 1981303            jack          pry  True   id      NaN            NaN
# 1981304            jack          pry  True   id      NaN            NaN
# 1981305            jack          pry  True   id      NaN            NaN
#
#          C1.V.SD.Sum  C1.V.Rat.Sum  C1.A.Mean.Sum  C1.A.SD.Sum  C1.A.Rat.Sum
# 0                NaN           NaN            NaN          NaN           NaN  \
# 1                NaN           NaN            NaN          NaN           NaN
# 2                NaN           NaN            NaN          NaN           NaN
# 3                NaN           NaN            NaN          NaN           NaN
# 4                NaN           NaN            NaN          NaN           NaN
# ...              ...           ...            ...          ...           ...
# 1981301          NaN           NaN            NaN          NaN           NaN
# 1981302          NaN           NaN            NaN          NaN           NaN
# 1981303          NaN           NaN            NaN          NaN           NaN
# 1981304          NaN           NaN            NaN          NaN           NaN
# 1981305          NaN           NaN            NaN          NaN           NaN
#
#          C1.D.Mean.Sum  C1.D.SD.Sum  C1.D.Rat.Sum C2.lemma  C2.V.Mean.Sum
# 0                  NaN          NaN           NaN      NaN            NaN  \
# 1                  NaN          NaN           NaN      NaN            NaN
# 2                  NaN          NaN           NaN      NaN            NaN
# 3                  NaN          NaN           NaN      NaN            NaN
# 4                  NaN          NaN           NaN      NaN            NaN
# ...                ...          ...           ...      ...            ...
# 1981301            NaN          NaN           NaN      pry           3.57
# 1981302            NaN          NaN           NaN      pry           3.57
# 1981303            NaN          NaN           NaN      pry           3.57
# 1981304            NaN          NaN           NaN      pry           3.57
# 1981305            NaN          NaN           NaN      pry           3.57
#
#          C2.V.SD.Sum  C2.V.Rat.Sum  C2.A.Mean.Sum  C2.A.SD.Sum  C2.A.Rat.Sum
# 0                NaN           NaN            NaN          NaN           NaN  \
# 1                NaN           NaN            NaN          NaN           NaN
# 2                NaN           NaN            NaN          NaN           NaN
# 3                NaN           NaN            NaN          NaN           NaN
# 4                NaN           NaN            NaN          NaN           NaN
# ...              ...           ...            ...          ...           ...
# 1981301         1.86          21.0            5.3         2.58          20.0
# 1981302         1.86          21.0            5.3         2.58          20.0
# 1981303         1.86          21.0            5.3         2.58          20.0
# 1981304         1.86          21.0            5.3         2.58          20.0
# 1981305         1.86          21.0            5.3         2.58          20.0
#
#          C2.D.Mean.Sum  C2.D.SD.Sum  C2.D.Rat.Sum
# 0                  NaN          NaN           NaN
# 1                  NaN          NaN           NaN
# 2                  NaN          NaN           NaN
# 3                  NaN          NaN           NaN
# 4                  NaN          NaN           NaN
# ...                ...          ...           ...
# 1981301           4.85         2.25          20.0
# 1981302           4.85         2.25          20.0
# 1981303           4.85         2.25          20.0
# 1981304           4.85         2.25          20.0
# 1981305           4.85         2.25          20.0
#
# [1981306 rows x 28 columns]

# %%
df= df_merge

# %%
# df.to_csv("../data/affectiveness/wn_colex_wkb.csv", index=False)

# %% [markdown]
# # Get Phonemes

# %%
with open("../data/phon/wikipron/data/scrape/lib/languages.json") as f:
    langs = json.load(f)

langs_colex = set(df.lang.tolist())

langs_pron= list()
lang_dict = dict()
for lang, d in langs.items():
    langs_pron.append(lang)
    lang_dict[lang] = (lang, d["iso639_name"])
    
    langs_pron.append(d["wiktionary_code"])
    lang_dict[d["wiktionary_code"]] = (lang, d["iso639_name"])
    
    if "dialect" in d:
        
        dia_d = d["dialect"]
        for k, v in dia_d.items():
            lang_dict[k]= (lang, v)
            langs_pron.append(k)

# %%
df
# Out:
#                      SENSE_LEMMA LANG             SYNSET1          SYNSET2
# 0        tropidoclonion_lineatum   BG  Tropidoclonion#n#1  lined_snake#n#1  \
# 1        tropidoclonion_lineatum   RU  Tropidoclonion#n#1  lined_snake#n#1
# 2        tropidoclonion_lineatum   UK  Tropidoclonion#n#1  lined_snake#n#1
# 3        tropidoclonion_lineatum   GA  Tropidoclonion#n#1  lined_snake#n#1
# 4        tropidoclonion_lineatum   RO  Tropidoclonion#n#1  lined_snake#n#1
# ...                          ...  ...                 ...              ...
# 1981301                   menuil   MS            jack#v#1          pry#v#1
# 1981302                   menuas   MS            jack#v#1          pry#v#1
# 1981303                   menuil   ID            jack#v#1          pry#v#1
# 1981304                   menuas   ID            jack#v#1          pry#v#1
# 1981305               mengungkit   ID            jack#v#1          pry#v#1
#
#                      C1           C2  diff lang C1.lemma  C1.V.Mean.Sum
# 0        tropidoclonion  lined_snake  True   bg      NaN            NaN  \
# 1        tropidoclonion  lined_snake  True   ru      NaN            NaN
# 2        tropidoclonion  lined_snake  True   uk      NaN            NaN
# 3        tropidoclonion  lined_snake  True   ga      NaN            NaN
# 4        tropidoclonion  lined_snake  True   ro      NaN            NaN
# ...                 ...          ...   ...  ...      ...            ...
# 1981301            jack          pry  True   ms      NaN            NaN
# 1981302            jack          pry  True   ms      NaN            NaN
# 1981303            jack          pry  True   id      NaN            NaN
# 1981304            jack          pry  True   id      NaN            NaN
# 1981305            jack          pry  True   id      NaN            NaN
#
#          C1.V.SD.Sum  C1.V.Rat.Sum  C1.A.Mean.Sum  C1.A.SD.Sum  C1.A.Rat.Sum
# 0                NaN           NaN            NaN          NaN           NaN  \
# 1                NaN           NaN            NaN          NaN           NaN
# 2                NaN           NaN            NaN          NaN           NaN
# 3                NaN           NaN            NaN          NaN           NaN
# 4                NaN           NaN            NaN          NaN           NaN
# ...              ...           ...            ...          ...           ...
# 1981301          NaN           NaN            NaN          NaN           NaN
# 1981302          NaN           NaN            NaN          NaN           NaN
# 1981303          NaN           NaN            NaN          NaN           NaN
# 1981304          NaN           NaN            NaN          NaN           NaN
# 1981305          NaN           NaN            NaN          NaN           NaN
#
#          C1.D.Mean.Sum  C1.D.SD.Sum  C1.D.Rat.Sum C2.lemma  C2.V.Mean.Sum
# 0                  NaN          NaN           NaN      NaN            NaN  \
# 1                  NaN          NaN           NaN      NaN            NaN
# 2                  NaN          NaN           NaN      NaN            NaN
# 3                  NaN          NaN           NaN      NaN            NaN
# 4                  NaN          NaN           NaN      NaN            NaN
# ...                ...          ...           ...      ...            ...
# 1981301            NaN          NaN           NaN      pry           3.57
# 1981302            NaN          NaN           NaN      pry           3.57
# 1981303            NaN          NaN           NaN      pry           3.57
# 1981304            NaN          NaN           NaN      pry           3.57
# 1981305            NaN          NaN           NaN      pry           3.57
#
#          C2.V.SD.Sum  C2.V.Rat.Sum  C2.A.Mean.Sum  C2.A.SD.Sum  C2.A.Rat.Sum
# 0                NaN           NaN            NaN          NaN           NaN  \
# 1                NaN           NaN            NaN          NaN           NaN
# 2                NaN           NaN            NaN          NaN           NaN
# 3                NaN           NaN            NaN          NaN           NaN
# 4                NaN           NaN            NaN          NaN           NaN
# ...              ...           ...            ...          ...           ...
# 1981301         1.86          21.0            5.3         2.58          20.0
# 1981302         1.86          21.0            5.3         2.58          20.0
# 1981303         1.86          21.0            5.3         2.58          20.0
# 1981304         1.86          21.0            5.3         2.58          20.0
# 1981305         1.86          21.0            5.3         2.58          20.0
#
#          C2.D.Mean.Sum  C2.D.SD.Sum  C2.D.Rat.Sum
# 0                  NaN          NaN           NaN
# 1                  NaN          NaN           NaN
# 2                  NaN          NaN           NaN
# 3                  NaN          NaN           NaN
# 4                  NaN          NaN           NaN
# ...                ...          ...           ...
# 1981301           4.85         2.25          20.0
# 1981302           4.85         2.25          20.0
# 1981303           4.85         2.25          20.0
# 1981304           4.85         2.25          20.0
# 1981305           4.85         2.25          20.0
#
# [1981306 rows x 28 columns]

# %%
lang_dict
# Out:
# {'aar': ('aar', 'Afar'),
#  'aa': ('aar', 'Afar'),
#  'abk': ('abk', 'Abkhazian'),
#  'ab': ('abk', 'Abkhazian'),
#  'acw': ('acw', 'Hijazi Arabic'),
#  'ady': ('ady', 'Adygei; Adyghe'),
#  'afb': ('afb', 'Gulf Arabic'),
#  'afr': ('afr', 'Afrikaans'),
#  'af': ('afr', 'Afrikaans'),
#  'ain': ('ain', 'Ainu (Japan)'),
#  'ajp': ('ajp', 'South Levantine Arabic'),
#  'akk': ('akk', 'Akkadian'),
#  'ale': ('ale', 'Aleut'),
#  'alr': ('alr', 'Alutor'),
#  'amh': ('amh', 'Amharic'),
#  'am': ('amh', 'Amharic'),
#  'ang': ('ang', 'Old English (ca. 450-1100)'),
#  'aot': ('aot', 'Atong (India)'),
#  'apw': ('apw', 'Western Apache'),
#  'ara': ('ara', 'Arabic'),
#  'ar': ('ara', 'Arabic'),
#  'arc': ('arc',
#   'Imperial Aramaic (700-300 BCE); Official Aramaic (700-300 BCE)'),
#  'ary': ('ary', 'Moroccan Arabic'),
#  'arz': ('arz', 'Egyptian Arabic'),
#  'asm': ('asm', 'Assamese'),
#  'as': ('asm', 'Assamese'),
#  'ast': ('ast', 'Asturian'),
#  'ayl': ('ayl', 'Libyan Arabic'),
#  'aze': ('aze', 'Azerbaijani'),
#  'az': ('aze', 'Azerbaijani'),
#  'azg': ('azg', 'San Pedro Amuzgos Amuzgo'),
#  'bak': ('bak', 'Bashkir'),
#  'ba': ('bak', 'Bashkir'),
#  'ban': ('ban', 'Balinese'),
#  'bcl': ('bcl', 'Central Bikol'),
#  'bdq': ('bdq', 'Bahnar'),
#  'bel': ('bel', 'Belarusian'),
#  'be': ('bel', 'Belarusian'),
#  'ben': ('ben', 'Bengali'),
#  'bn': ('ben', 'Bengali'),
#  'blt': ('blt', 'Tai Dam'),
#  'bod': ('bod', 'Tibetan'),
#  'bo': ('bod', 'Tibetan'),
#  'bre': ('bre', 'Breton'),
#  'br': ('bre', 'Breton'),
#  'bul': ('bul', 'Bulgarian'),
#  'bg': ('bul', 'Bulgarian'),
#  'cat': ('cat', 'Catalan; Valencian'),
#  'ca': ('spa', 'Castilian'),
#  'cbn': ('cbn', 'Nyahkur'),
#  'ceb': ('ceb', 'Cebuano'),
#  'ces': ('ces', 'Czech'),
#  'cs': ('ces', 'Czech'),
#  'chb': ('chb', 'Chibcha'),
#  'che': ('che', 'Chechen'),
#  'ce': ('che', 'Chechen'),
#  'cho': ('cho', 'Choctaw'),
#  'ckb': ('ckb', 'Central Kurdish'),
#  'cmn': ('cmn', 'Mandarin Chinese'),
#  'zh': ('cmn', 'Mandarin Chinese'),
#  'cnk': ('cnk', 'Khumi Chin'),
#  'cop': ('cop', 'Coptic'),
#  'cor': ('cor', 'Cornish'),
#  'kw': ('cor', 'Cornish'),
#  'cos': ('cos', 'Corsican'),
#  'co': ('cos', 'Corsican'),
#  'crk': ('crk', 'Plains Cree'),
#  'crx': ('crx', 'Carrier'),
#  'csb': ('csb', 'Kashubian'),
#  'cym': ('cym', 'Welsh'),
#  'cy': ('cym', 'Welsh'),
#  'nw': ('cym', 'North Wales'),
#  'sw': ('cym', 'South Wales'),
#  'dan': ('dan', 'Danish'),
#  'da': ('dan', 'Danish'),
#  'deu': ('deu', 'German'),
#  'de': ('deu', 'German'),
#  'div': ('div', 'Dhivehi, Divehi, Maldivian'),
#  'dv': ('div', 'Dhivehi, Divehi, Maldivian'),
#  'dlm': ('dlm', 'Dalmatian'),
#  'dng': ('dng', 'Dungan'),
#  'dsb': ('dsb', 'Lower Sorbian'),
#  'dum': ('dum', 'Middle Dutch (ca. 1050-1350)'),
#  'dzo': ('dzo', 'Dzongkha'),
#  'dz': ('dzo', 'Dzongkha'),
#  'egl': ('egl', 'Emilian'),
#  'egy': ('egy', 'Egyptian (Ancient)'),
#  'ell': ('ell', 'Modern Greek (1453-)'),
#  'el': ('ell', 'Modern Greek (1453-)'),
#  'eng': ('eng', 'English'),
#  'en': ('eng', 'English'),
#  'us': ('eng', 'US | General American'),
#  'uk': ('ukr', 'Ukrainian'),
#  'enm': ('enm', 'Middle English (1100-1500)'),
#  'epo': ('epo', 'Esperanto'),
#  'eo': ('epo', 'Esperanto'),
#  'est': ('est', 'Estonian'),
#  'et': ('est', 'Estonian'),
#  'ett': ('ett', 'Etruscan'),
#  'eus': ('eus', 'Basque'),
#  'eu': ('eus', 'Basque'),
#  'ewe': ('ewe', 'Ewe'),
#  'ee': ('ewe', 'Ewe'),
#  'fao': ('fao', 'Faroese'),
#  'fo': ('fao', 'Faroese'),
#  'fas': ('fas', 'Persian'),
#  'fa': ('fas', 'Persian'),
#  'fin': ('fin', 'Finnish'),
#  'fi': ('fin', 'Finnish'),
#  'fra': ('fra', 'French'),
#  'fr': ('fra', 'French'),
#  'fro': ('fro', 'Old French (842-ca. 1400)'),
#  'frr': ('frr', 'Northern Frisian'),
#  'fry': ('fry', 'Western Frisian'),
#  'fy': ('fry', 'Western Frisian'),
#  'gla': ('gla', 'Gaelic; Scottish Gaelic'),
#  'gd': ('gla', 'Gaelic; Scottish Gaelic'),
#  'gle': ('gle', 'Irish'),
#  'ga': ('gle', 'Irish'),
#  'glg': ('glg', 'Galician'),
#  'gl': ('glg', 'Galician'),
#  'glv': ('glv', 'Manx'),
#  'gv': ('glv', 'Manx'),
#  'gml': ('gml', 'Middle Low German'),
#  'goh': ('goh', 'Old High German (ca. 750-1050)'),
#  'got': ('got', 'Gothic'),
#  'grc': ('grc', 'Ancient Greek (to 1453)'),
#  'gsw': ('gsw', 'Swiss German'),
#  'guj': ('guj', 'Gujarati'),
#  'gu': ('guj', 'Gujarati'),
#  'gur': ('gur', 'Farefare'),
#  'hau': ('hau', 'Hausa'),
#  'ha': ('hau', 'Hausa'),
#  'haw': ('haw', 'Hawaiian'),
#  'hbs': ('hbs', 'Serbo-Croatian'),
#  'sh': ('hbs', 'Serbo-Croatian'),
#  'heb': ('heb', 'Hebrew'),
#  'he': ('heb', 'Hebrew'),
#  'hin': ('hin', 'Hindi'),
#  'hi': ('hin', 'Hindi'),
#  'hrx': ('hrx', 'Hunsrik'),
#  'hts': ('hts', 'Hadza'),
#  'hun': ('hun', 'Hungarian'),
#  'hu': ('hun', 'Hungarian'),
#  'huu': ('huu', 'Murui Huitoto'),
#  'hye': ('hye', 'Armenian'),
#  'hy': ('hye', 'Armenian'),
#  'w': ('hye', 'Western Armenian, standard'),
#  'e': ('hye', 'Eastern Armenian, standard'),
#  'iba': ('iba', 'Iban'),
#  'ido': ('ido', 'Ido'),
#  'io': ('ido', 'Ido'),
#  'ilo': ('ilo', 'Iloko'),
#  'ina': ('ina', 'Interlingua (International Auxiliary Language Association)'),
#  'ia': ('ina', 'Interlingua (International Auxiliary Language Association)'),
#  'ind': ('ind', 'Indonesian'),
#  'id': ('ind', 'Indonesian'),
#  'isl': ('isl', 'Icelandic'),
#  'is': ('isl', 'Icelandic'),
#  'ita': ('ita', 'Italian'),
#  'it': ('ita', 'Italian'),
#  'izh': ('izh', 'Ingrian'),
#  'jam': ('jam', 'Jamaican Creole English'),
#  'jje': ('jje', 'Jejueo'),
#  'jpn': ('jpn', 'Japanese'),
#  'ja': ('jpn', 'Japanese'),
#  'kal': ('kal', 'Kalaallisut'),
#  'kl': ('kal', 'Kalaallisut'),
#  'kan': ('kan', 'Kannada'),
#  'kn': ('kan', 'Kannada'),
#  'kas': ('kas', 'Kashmiri'),
#  'ks': ('kas', 'Kashmiri'),
#  'kat': ('kat', 'Georgian'),
#  'ka': ('kat', 'Georgian'),
#  'kaz': ('kaz', 'Kazakh'),
#  'kk': ('kaz', 'Kazakh'),
#  'kbd': ('kbd', 'Kabardian'),
#  'khb': ('khb', 'Lü'),
#  'khm': ('khm', 'Khmer'),
#  'km': ('khm', 'Khmer'),
#  'kik': ('kik', 'Kikuyu'),
#  'ki': ('kik', 'Kikuyu'),
#  'kir': ('kir', 'Kirghiz'),
#  'ky': ('kir', 'Kirghiz'),
#  'kld': ('kld', 'Gamilaraay'),
#  'kmr': ('kmr', 'Northern Kurdish'),
#  'kok': ('kok', 'Konkani (macrolanguage)'),
#  'kor': ('kor', 'Korean'),
#  'ko': ('kor', 'Korean'),
#  'kpv': ('kpv', 'Komi-Zyrian'),
#  'krl': ('krl', 'Karelian'),
#  'kxd': ('kxd', 'Brunei'),
#  'lad': ('lad', 'Ladino'),
#  'lao': ('lao', 'Lao'),
#  'lo': ('lao', 'Lao'),
#  'lat': ('lat', 'Latin'),
#  'la': ('spa', 'Latin America'),
#  'clas': ('lat', 'Classical'),
#  'eccl': ('lat', 'Ecclesiastical'),
#  'vulg': ('lat', 'Vulgar'),
#  'lav': ('lav', 'Latvian'),
#  'lv': ('lav', 'Latvian'),
#  'lcp': ('lcp', 'Western Lawa'),
#  'lif': ('lif', 'Limbu'),
#  'lij': ('lij', 'Ligurian'),
#  'lim': ('lim', 'Limburgan'),
#  'li': ('lim', 'Limburgan'),
#  'lit': ('lit', 'Lithuanian'),
#  'lt': ('lit', 'Lithuanian'),
#  'liv': ('liv', 'Liv'),
#  'lmo': ('lmo', 'Lombard'),
#  'lmy': ('lmy', 'Lamboya'),
#  'lsi': ('lsi', 'Lashi'),
#  'ltg': ('ltg', 'Latgalian'),
#  'ltz': ('ltz', 'Letzeburgesch; Luxembourgish'),
#  'lb': ('ltz', 'Letzeburgesch; Luxembourgish'),
#  'lwl': ('lwl', 'Eastern Lawa'),
#  'lzz': ('lzz', 'Laz'),
#  'mah': ('mah', 'Marshallese'),
#  'mh': ('mah', 'Marshallese'),
#  'mak': ('mak', 'Makasar'),
#  'mal': ('mal', 'Malayalam'),
#  'ml': ('mal', 'Malayalam'),
#  'mar': ('mar', 'Marathi'),
#  'mr': ('mar', 'Marathi'),
#  'mdf': ('mdf', 'Moksha'),
#  'mfe': ('mfe', 'Morisyen'),
#  'mga': ('mga', 'Middle Irish (900-1200)'),
#  'mic': ('mic', "Mi'kmaq"),
#  'mkd': ('mkd', 'Macedonian'),
#  'mk': ('mkd', 'Macedonian'),
#  'mlg': ('mlg', 'Malagasy'),
#  'mg': ('mlg', 'Malagasy'),
#  'mlt': ('mlt', 'Maltese'),
#  'mt': ('mlt', 'Maltese'),
#  'mnc': ('mnc', 'Manchu'),
#  'mnw': ('mnw', 'Mon'),
#  'mon': ('mon', 'Mongolian'),
#  'mn': ('mon', 'Mongolian'),
#  'mqs': ('mqs', 'West Makian'),
#  'msa': ('msa', 'Malay (macrolanguage)'),
#  'ms': ('msa', 'Malay (macrolanguage)'),
#  'mvi': ('mvi', 'Miyako'),
#  'mww': ('mww', 'Hmong Daw'),
#  'mya': ('mya', 'Burmese'),
#  'my': ('mya', 'Burmese'),
#  'nan': ('nan', 'Min Nan Chinese'),
#  'xi': ('nan', 'Xiamen'),
#  'nap': ('nap', 'Neapolitan'),
#  'nav': ('nav', 'Navajo'),
#  'nv': ('nav', 'Navajo'),
#  'nci': ('nci', 'Classical Nahuatl'),
#  'nds': ('nds', 'Low German'),
#  'nep': ('nep', 'Nepali (macrolanguage)'),
#  'ne': ('nep', 'Nepali (macrolanguage)'),
#  'new': ('new', 'Newari'),
#  'nhg': ('nhg', 'Tetelcingo Nahuatl'),
#  'nhn': ('nhn', 'Central Nahuatl'),
#  'nhx': ('nhx', 'Isthmus-Mecayapan Nahuatl'),
#  'nld': ('nld', 'Dutch; Flemish'),
#  'nl': ('nld', 'Dutch; Flemish'),
#  'nmy': ('nmy', 'Namuyi'),
#  'nno': ('nno', 'Norwegian Nynorsk'),
#  'nn': ('nno', 'Norwegian Nynorsk'),
#  'nob': ('nob', 'Norwegian Bokmål'),
#  'nb': ('nob', 'Norwegian Bokmål'),
#  'non': ('non', 'Old Norse'),
#  'nor': ('nor', 'Norwegian'),
#  'no': ('nor', 'Norwegian'),
#  'nrf': ('nrf', 'Jèrriais'),
#  'nya': ('nya', 'Nyanja'),
#  'ny': ('nya', 'Nyanja'),
#  'oci': ('oci', 'Occitan (post 1500)'),
#  'oc': ('oci', 'Occitan (post 1500)'),
#  'ofs': ('ofs', 'Old Frisian'),
#  'okm': ('okm', 'Middle Korean (10th-16th cent.)'),
#  'olo': ('olo', 'Livvi'),
#  'ori': ('ori', 'Oriya (macrolanguage)'),
#  'or': ('ori', 'Oriya (macrolanguage)'),
#  'osp': ('osp', 'Old Spanish'),
#  'osx': ('osx', 'Old Saxon'),
#  'ota': ('ota', 'Ottoman Turkish (1500-1928)'),
#  'pan': ('pan', 'Panjabi'),
#  'pa': ('pan', 'Panjabi'),
#  'pbv': ('pbv', 'Pnar'),
#  'pcc': ('pcc', 'Bouyei'),
#  'pdc': ('pdc', 'Pennsylvania German'),
#  'phl': ('phl', 'Phalura'),
#  'pjt': ('pjt', 'Pitjantjatjara'),
#  'pms': ('pms', 'Piemontese'),
#  'pol': ('pol', 'Polish'),
#  'pl': ('pol', 'Polish'),
#  'por': ('por', 'Portuguese'),
#  'pt': ('por', 'Portuguese'),
#  'bz': ('por', 'Brazil'),
#  'po': ('por', 'Portugal'),
#  'pox': ('pox', 'Polabian'),
#  'ppl': ('ppl', 'Pipil'),
#  'pus': ('pus', 'Pushto'),
#  'ps': ('pus', 'Pushto'),
#  'quc': ('quc', "K'iche'"),
#  'rgn': ('rgn', 'Romagnol'),
#  'ron': ('ron', 'Romanian; Moldavian; Moldovan'),
#  'ro': ('ron', 'Romanian; Moldavian; Moldovan'),
#  'rup': ('rup', 'Macedo-Romanian'),
#  'rus': ('rus', 'Russian'),
#  'ru': ('rus', 'Russian'),
#  'ryu': ('ryu', 'Central Okinawan'),
#  'sah': ('sah', 'Yakut'),
#  'san': ('san', 'Sanskrit'),
#  'sa': ('san', 'Sanskrit'),
#  'sce': ('sce', 'Dongxiang'),
#  'scn': ('scn', 'Sicilian'),
#  'sco': ('sco', 'Scots'),
#  'sga': ('sga', 'Old Irish (to 900)'),
#  'shn': ('shn', 'Shan'),
#  'sid': ('sid', 'Sidamo'),
#  'slk': ('slk', 'Slovak'),
#  'sk': ('slk', 'Slovak'),
#  'slv': ('slv', 'Slovenian'),
#  'sl': ('slv', 'Slovenian'),
#  'sme': ('sme', 'Northern Sami'),
#  'se': ('sme', 'Northern Sami'),
#  'sms': ('sms', 'Skolt Sami'),
#  'spa': ('spa', 'Spanish; Castilian'),
#  'es': ('spa', 'Spanish; Castilian'),
#  'sqi': ('sqi', 'Albanian'),
#  'sq': ('sqi', 'Albanian'),
#  'srd': ('srd', 'Sardinian'),
#  'sc': ('srd', 'Sardinian'),
#  'srn': ('srn', 'Sranan Tongo'),
#  'stq': ('stq', 'Saterfriesisch'),
#  'swe': ('swe', 'Swedish'),
#  'sv': ('swe', 'Swedish'),
#  'syc': ('syc', 'Classical Syriac'),
#  'syl': ('syl', 'Sylheti'),
#  'tam': ('tam', 'Tamil'),
#  'ta': ('tam', 'Tamil'),
#  'tby': ('tby', 'Tabaru'),
#  'tel': ('tel', 'Telugu'),
#  'te': ('tel', 'Telugu'),
#  'tft': ('tft', 'Ternate'),
#  'tgk': ('tgk', 'Tajik'),
#  'tg': ('tgk', 'Tajik'),
#  'tgl': ('tgl', 'Tagalog'),
#  'tl': ('tgl', 'Tagalog'),
#  'tha': ('tha', 'Thai'),
#  'th': ('tha', 'Thai'),
#  'tkl': ('tkl', 'Tokelau'),
#  'ton': ('ton', 'Tonga (Tonga Islands)'),
#  'to': ('ton', 'Tonga (Tonga Islands)'),
#  'tpw': ('tpw', 'Tupí'),
#  'tuk': ('tuk', 'Turkmen'),
#  'tk': ('tuk', 'Turkmen'),
#  'tur': ('tur', 'Turkish'),
#  'tr': ('tur', 'Turkish'),
#  'twf': ('twf', 'Northern Tiwa'),
#  'tyv': ('tyv', 'Tuvinian'),
#  'tzm': ('tzm', 'Central Atlas Tamazight'),
#  'tzo': ('tzo', 'Tzotzil'),
#  'uig': ('uig', 'Uighur'),
#  'ug': ('uig', 'Uighur'),
#  'ukr': ('ukr', 'Ukrainian'),
#  'urd': ('urd', 'Urdu'),
#  'ur': ('urd', 'Urdu'),
#  'urk': ('urk', "Urak Lawoi'"),
#  'vie': ('vie', 'Vietnamese'),
#  'vi': ('vie', 'Vietnamese'),
#  'hanoi': ('vie', 'Hà Nội'),
#  'hcmc': ('vie', 'Hồ Chí Minh City'),
#  'hue': ('vie', 'Huế'),
#  'tc': ('vie', 'Vinh, Thanh Chương'),
#  'ht': ('vie', 'Hà Tĩnh'),
#  'vol': ('vol', 'Volapük'),
#  'vo': ('vol', 'Volapük'),
#  'wau': ('wau', 'Waurá'),
#  'wiy': ('wiy', 'Wiyot'),
#  'wlm': ('wlm', 'Middle Welsh'),
#  'xal': ('xal', 'Kalmyk, Oirat'),
#  'xho': ('xho', 'Xhosa'),
#  'xh': ('xho', 'Xhosa'),
#  'ybi': ('ybi', 'Yamphu'),
#  'ycl': ('ycl', 'Lolopo'),
#  'yid': ('yid', 'Yiddish'),
#  'yi': ('yid', 'Yiddish'),
#  'yor': ('yor', 'Yoruba'),
#  'yo': ('yor', 'Yoruba'),
#  'yue': ('yue', 'Yue Chinese'),
#  'yux': ('yux', 'Southern Yukaghir'),
#  'zha': ('zha', 'Zhuang'),
#  'za': ('zha', 'Zhuang'),
#  'zom': ('zom', 'Zou'),
#  'zul': ('zul', 'Zulu'),
#  'zu': ('zul', 'Zulu'),
#  'zza': ('zza', 'Zaza')}

# %%
len(langs_pron), len(langs_colex), len(langs_colex.intersection(set(langs_pron)))
# Out:
# (543, 520, 214)

# %%
len(langs_pron), len(langs_colex), len(langs_colex.intersection(set(langs_pron)))
# Out:
# (543, 311, 171)

# %%
df
# Out:
#                      SENSE_LEMMA LANG             SYNSET1          SYNSET2
# 0        tropidoclonion_lineatum   BG  Tropidoclonion#n#1  lined_snake#n#1  \
# 1        tropidoclonion_lineatum   RU  Tropidoclonion#n#1  lined_snake#n#1
# 2        tropidoclonion_lineatum   UK  Tropidoclonion#n#1  lined_snake#n#1
# 3        tropidoclonion_lineatum   GA  Tropidoclonion#n#1  lined_snake#n#1
# 4        tropidoclonion_lineatum   RO  Tropidoclonion#n#1  lined_snake#n#1
# ...                          ...  ...                 ...              ...
# 1981301                   menuil   MS            jack#v#1          pry#v#1
# 1981302                   menuas   MS            jack#v#1          pry#v#1
# 1981303                   menuil   ID            jack#v#1          pry#v#1
# 1981304                   menuas   ID            jack#v#1          pry#v#1
# 1981305               mengungkit   ID            jack#v#1          pry#v#1
#
#                      C1           C2  diff lang C1.lemma  C1.V.Mean.Sum
# 0        tropidoclonion  lined_snake  True   bg      NaN            NaN  \
# 1        tropidoclonion  lined_snake  True   ru      NaN            NaN
# 2        tropidoclonion  lined_snake  True   uk      NaN            NaN
# 3        tropidoclonion  lined_snake  True   ga      NaN            NaN
# 4        tropidoclonion  lined_snake  True   ro      NaN            NaN
# ...                 ...          ...   ...  ...      ...            ...
# 1981301            jack          pry  True   ms      NaN            NaN
# 1981302            jack          pry  True   ms      NaN            NaN
# 1981303            jack          pry  True   id      NaN            NaN
# 1981304            jack          pry  True   id      NaN            NaN
# 1981305            jack          pry  True   id      NaN            NaN
#
#          C1.V.SD.Sum  C1.V.Rat.Sum  C1.A.Mean.Sum  C1.A.SD.Sum  C1.A.Rat.Sum
# 0                NaN           NaN            NaN          NaN           NaN  \
# 1                NaN           NaN            NaN          NaN           NaN
# 2                NaN           NaN            NaN          NaN           NaN
# 3                NaN           NaN            NaN          NaN           NaN
# 4                NaN           NaN            NaN          NaN           NaN
# ...              ...           ...            ...          ...           ...
# 1981301          NaN           NaN            NaN          NaN           NaN
# 1981302          NaN           NaN            NaN          NaN           NaN
# 1981303          NaN           NaN            NaN          NaN           NaN
# 1981304          NaN           NaN            NaN          NaN           NaN
# 1981305          NaN           NaN            NaN          NaN           NaN
#
#          C1.D.Mean.Sum  C1.D.SD.Sum  C1.D.Rat.Sum C2.lemma  C2.V.Mean.Sum
# 0                  NaN          NaN           NaN      NaN            NaN  \
# 1                  NaN          NaN           NaN      NaN            NaN
# 2                  NaN          NaN           NaN      NaN            NaN
# 3                  NaN          NaN           NaN      NaN            NaN
# 4                  NaN          NaN           NaN      NaN            NaN
# ...                ...          ...           ...      ...            ...
# 1981301            NaN          NaN           NaN      pry           3.57
# 1981302            NaN          NaN           NaN      pry           3.57
# 1981303            NaN          NaN           NaN      pry           3.57
# 1981304            NaN          NaN           NaN      pry           3.57
# 1981305            NaN          NaN           NaN      pry           3.57
#
#          C2.V.SD.Sum  C2.V.Rat.Sum  C2.A.Mean.Sum  C2.A.SD.Sum  C2.A.Rat.Sum
# 0                NaN           NaN            NaN          NaN           NaN  \
# 1                NaN           NaN            NaN          NaN           NaN
# 2                NaN           NaN            NaN          NaN           NaN
# 3                NaN           NaN            NaN          NaN           NaN
# 4                NaN           NaN            NaN          NaN           NaN
# ...              ...           ...            ...          ...           ...
# 1981301         1.86          21.0            5.3         2.58          20.0
# 1981302         1.86          21.0            5.3         2.58          20.0
# 1981303         1.86          21.0            5.3         2.58          20.0
# 1981304         1.86          21.0            5.3         2.58          20.0
# 1981305         1.86          21.0            5.3         2.58          20.0
#
#          C2.D.Mean.Sum  C2.D.SD.Sum  C2.D.Rat.Sum LANG_PRON
# 0                  NaN          NaN           NaN       bul  \
# 1                  NaN          NaN           NaN       rus
# 2                  NaN          NaN           NaN       ukr
# 3                  NaN          NaN           NaN       gle
# 4                  NaN          NaN           NaN       ron
# ...                ...          ...           ...       ...
# 1981301           4.85         2.25          20.0       msa
# 1981302           4.85         2.25          20.0       msa
# 1981303           4.85         2.25          20.0       ind
# 1981304           4.85         2.25          20.0       ind
# 1981305           4.85         2.25          20.0       ind
#
#                              LANG_NAME
# 0                            Bulgarian
# 1                              Russian
# 2                            Ukrainian
# 3                                Irish
# 4        Romanian; Moldavian; Moldovan
# ...                                ...
# 1981301          Malay (macrolanguage)
# 1981302          Malay (macrolanguage)
# 1981303                     Indonesian
# 1981304                     Indonesian
# 1981305                     Indonesian
#
# [1922335 rows x 30 columns]

# %%
df["LANG_PRON"]=df["lang"].apply(lambda x: lang_dict[x][0] if x in lang_dict else x)
df["LANG_NAME"] = df["lang"].apply(lambda x: lang_dict[x][1] if x in lang_dict else x)

# %%
# df_inter = df[df["lang"].isin(langs_pron)]

# %%
# df_inter["LANG_PRON"] = df_inter["lang"].apply(lambda x: lang_dict[x][0])
# df_inter["LANG_NAME"] = df_inter["lang"].apply(lambda x: lang_dict[x][1])
# Out:
# /var/folders/bj/qp6k2wl11h5gpn8j4hg0tgf40000gn/T/ipykernel_34572/2000428589.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_inter["LANG_PRON"] = df_inter["lang"].apply(lambda x: lang_dict[x][0])
# /var/folders/bj/qp6k2wl11h5gpn8j4hg0tgf40000gn/T/ipykernel_34572/2000428589.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_inter["LANG_NAME"] = df_inter["lang"].apply(lambda x: lang_dict[x][1])

# %%
df.drop_duplicates()
# Out:
#                      SENSE_LEMMA LANG             SYNSET1          SYNSET2
# 0        tropidoclonion_lineatum   BG  Tropidoclonion#n#1  lined_snake#n#1  \
# 1        tropidoclonion_lineatum   RU  Tropidoclonion#n#1  lined_snake#n#1
# 2        tropidoclonion_lineatum   UK  Tropidoclonion#n#1  lined_snake#n#1
# 3        tropidoclonion_lineatum   GA  Tropidoclonion#n#1  lined_snake#n#1
# 4        tropidoclonion_lineatum   RO  Tropidoclonion#n#1  lined_snake#n#1
# ...                          ...  ...                 ...              ...
# 1981301                   menuil   MS            jack#v#1          pry#v#1
# 1981302                   menuas   MS            jack#v#1          pry#v#1
# 1981303                   menuil   ID            jack#v#1          pry#v#1
# 1981304                   menuas   ID            jack#v#1          pry#v#1
# 1981305               mengungkit   ID            jack#v#1          pry#v#1
#
#                      C1           C2  diff lang C1.lemma  C1.V.Mean.Sum
# 0        tropidoclonion  lined_snake  True   bg      NaN            NaN  \
# 1        tropidoclonion  lined_snake  True   ru      NaN            NaN
# 2        tropidoclonion  lined_snake  True   uk      NaN            NaN
# 3        tropidoclonion  lined_snake  True   ga      NaN            NaN
# 4        tropidoclonion  lined_snake  True   ro      NaN            NaN
# ...                 ...          ...   ...  ...      ...            ...
# 1981301            jack          pry  True   ms      NaN            NaN
# 1981302            jack          pry  True   ms      NaN            NaN
# 1981303            jack          pry  True   id      NaN            NaN
# 1981304            jack          pry  True   id      NaN            NaN
# 1981305            jack          pry  True   id      NaN            NaN
#
#          C1.V.SD.Sum  C1.V.Rat.Sum  C1.A.Mean.Sum  C1.A.SD.Sum  C1.A.Rat.Sum
# 0                NaN           NaN            NaN          NaN           NaN  \
# 1                NaN           NaN            NaN          NaN           NaN
# 2                NaN           NaN            NaN          NaN           NaN
# 3                NaN           NaN            NaN          NaN           NaN
# 4                NaN           NaN            NaN          NaN           NaN
# ...              ...           ...            ...          ...           ...
# 1981301          NaN           NaN            NaN          NaN           NaN
# 1981302          NaN           NaN            NaN          NaN           NaN
# 1981303          NaN           NaN            NaN          NaN           NaN
# 1981304          NaN           NaN            NaN          NaN           NaN
# 1981305          NaN           NaN            NaN          NaN           NaN
#
#          C1.D.Mean.Sum  C1.D.SD.Sum  C1.D.Rat.Sum C2.lemma  C2.V.Mean.Sum
# 0                  NaN          NaN           NaN      NaN            NaN  \
# 1                  NaN          NaN           NaN      NaN            NaN
# 2                  NaN          NaN           NaN      NaN            NaN
# 3                  NaN          NaN           NaN      NaN            NaN
# 4                  NaN          NaN           NaN      NaN            NaN
# ...                ...          ...           ...      ...            ...
# 1981301            NaN          NaN           NaN      pry           3.57
# 1981302            NaN          NaN           NaN      pry           3.57
# 1981303            NaN          NaN           NaN      pry           3.57
# 1981304            NaN          NaN           NaN      pry           3.57
# 1981305            NaN          NaN           NaN      pry           3.57
#
#          C2.V.SD.Sum  C2.V.Rat.Sum  C2.A.Mean.Sum  C2.A.SD.Sum  C2.A.Rat.Sum
# 0                NaN           NaN            NaN          NaN           NaN  \
# 1                NaN           NaN            NaN          NaN           NaN
# 2                NaN           NaN            NaN          NaN           NaN
# 3                NaN           NaN            NaN          NaN           NaN
# 4                NaN           NaN            NaN          NaN           NaN
# ...              ...           ...            ...          ...           ...
# 1981301         1.86          21.0            5.3         2.58          20.0
# 1981302         1.86          21.0            5.3         2.58          20.0
# 1981303         1.86          21.0            5.3         2.58          20.0
# 1981304         1.86          21.0            5.3         2.58          20.0
# 1981305         1.86          21.0            5.3         2.58          20.0
#
#          C2.D.Mean.Sum  C2.D.SD.Sum  C2.D.Rat.Sum LANG_PRON
# 0                  NaN          NaN           NaN       bul  \
# 1                  NaN          NaN           NaN       rus
# 2                  NaN          NaN           NaN       ukr
# 3                  NaN          NaN           NaN       gle
# 4                  NaN          NaN           NaN       ron
# ...                ...          ...           ...       ...
# 1981301           4.85         2.25          20.0       msa
# 1981302           4.85         2.25          20.0       msa
# 1981303           4.85         2.25          20.0       ind
# 1981304           4.85         2.25          20.0       ind
# 1981305           4.85         2.25          20.0       ind
#
#                              LANG_NAME
# 0                            Bulgarian
# 1                              Russian
# 2                            Ukrainian
# 3                                Irish
# 4        Romanian; Moldavian; Moldovan
# ...                                ...
# 1981301          Malay (macrolanguage)
# 1981302          Malay (macrolanguage)
# 1981303                     Indonesian
# 1981304                     Indonesian
# 1981305                     Indonesian
#
# [1981306 rows x 30 columns]

# %%
df["LEN"]=df["LANG_PRON"].str.len()

# %%
df = df.drop_duplicates(subset=["SENSE_LEMMA", "lang", "SYNSET1", "SYNSET2"])

# %%
df
# Out:
#                      SENSE_LEMMA LANG             SYNSET1          SYNSET2
# 0        tropidoclonion_lineatum   BG  Tropidoclonion#n#1  lined_snake#n#1  \
# 1        tropidoclonion_lineatum   RU  Tropidoclonion#n#1  lined_snake#n#1
# 2        tropidoclonion_lineatum   UK  Tropidoclonion#n#1  lined_snake#n#1
# 3        tropidoclonion_lineatum   GA  Tropidoclonion#n#1  lined_snake#n#1
# 4        tropidoclonion_lineatum   RO  Tropidoclonion#n#1  lined_snake#n#1
# ...                          ...  ...                 ...              ...
# 1981301                   menuil   MS            jack#v#1          pry#v#1
# 1981302                   menuas   MS            jack#v#1          pry#v#1
# 1981303                   menuil   ID            jack#v#1          pry#v#1
# 1981304                   menuas   ID            jack#v#1          pry#v#1
# 1981305               mengungkit   ID            jack#v#1          pry#v#1
#
#                      C1           C2  diff lang C1.lemma  C1.V.Mean.Sum
# 0        tropidoclonion  lined_snake  True   bg      NaN            NaN  \
# 1        tropidoclonion  lined_snake  True   ru      NaN            NaN
# 2        tropidoclonion  lined_snake  True   uk      NaN            NaN
# 3        tropidoclonion  lined_snake  True   ga      NaN            NaN
# 4        tropidoclonion  lined_snake  True   ro      NaN            NaN
# ...                 ...          ...   ...  ...      ...            ...
# 1981301            jack          pry  True   ms      NaN            NaN
# 1981302            jack          pry  True   ms      NaN            NaN
# 1981303            jack          pry  True   id      NaN            NaN
# 1981304            jack          pry  True   id      NaN            NaN
# 1981305            jack          pry  True   id      NaN            NaN
#
#          C1.V.SD.Sum  C1.V.Rat.Sum  C1.A.Mean.Sum  C1.A.SD.Sum  C1.A.Rat.Sum
# 0                NaN           NaN            NaN          NaN           NaN  \
# 1                NaN           NaN            NaN          NaN           NaN
# 2                NaN           NaN            NaN          NaN           NaN
# 3                NaN           NaN            NaN          NaN           NaN
# 4                NaN           NaN            NaN          NaN           NaN
# ...              ...           ...            ...          ...           ...
# 1981301          NaN           NaN            NaN          NaN           NaN
# 1981302          NaN           NaN            NaN          NaN           NaN
# 1981303          NaN           NaN            NaN          NaN           NaN
# 1981304          NaN           NaN            NaN          NaN           NaN
# 1981305          NaN           NaN            NaN          NaN           NaN
#
#          C1.D.Mean.Sum  C1.D.SD.Sum  C1.D.Rat.Sum C2.lemma  C2.V.Mean.Sum
# 0                  NaN          NaN           NaN      NaN            NaN  \
# 1                  NaN          NaN           NaN      NaN            NaN
# 2                  NaN          NaN           NaN      NaN            NaN
# 3                  NaN          NaN           NaN      NaN            NaN
# 4                  NaN          NaN           NaN      NaN            NaN
# ...                ...          ...           ...      ...            ...
# 1981301            NaN          NaN           NaN      pry           3.57
# 1981302            NaN          NaN           NaN      pry           3.57
# 1981303            NaN          NaN           NaN      pry           3.57
# 1981304            NaN          NaN           NaN      pry           3.57
# 1981305            NaN          NaN           NaN      pry           3.57
#
#          C2.V.SD.Sum  C2.V.Rat.Sum  C2.A.Mean.Sum  C2.A.SD.Sum  C2.A.Rat.Sum
# 0                NaN           NaN            NaN          NaN           NaN  \
# 1                NaN           NaN            NaN          NaN           NaN
# 2                NaN           NaN            NaN          NaN           NaN
# 3                NaN           NaN            NaN          NaN           NaN
# 4                NaN           NaN            NaN          NaN           NaN
# ...              ...           ...            ...          ...           ...
# 1981301         1.86          21.0            5.3         2.58          20.0
# 1981302         1.86          21.0            5.3         2.58          20.0
# 1981303         1.86          21.0            5.3         2.58          20.0
# 1981304         1.86          21.0            5.3         2.58          20.0
# 1981305         1.86          21.0            5.3         2.58          20.0
#
#          C2.D.Mean.Sum  C2.D.SD.Sum  C2.D.Rat.Sum LANG_PRON
# 0                  NaN          NaN           NaN       bul  \
# 1                  NaN          NaN           NaN       rus
# 2                  NaN          NaN           NaN       ukr
# 3                  NaN          NaN           NaN       gle
# 4                  NaN          NaN           NaN       ron
# ...                ...          ...           ...       ...
# 1981301           4.85         2.25          20.0       msa
# 1981302           4.85         2.25          20.0       msa
# 1981303           4.85         2.25          20.0       ind
# 1981304           4.85         2.25          20.0       ind
# 1981305           4.85         2.25          20.0       ind
#
#                              LANG_NAME  LEN
# 0                            Bulgarian  3.0
# 1                              Russian  3.0
# 2                            Ukrainian  3.0
# 3                                Irish  3.0
# 4        Romanian; Moldavian; Moldovan  3.0
# ...                                ...  ...
# 1981301          Malay (macrolanguage)  3.0
# 1981302          Malay (macrolanguage)  3.0
# 1981303                     Indonesian  3.0
# 1981304                     Indonesian  3.0
# 1981305                     Indonesian  3.0
#
# [1980472 rows x 31 columns]

# %%
df["lemma_lang"]= df["SENSE_LEMMA"]+"_"+df["LANG_PRON"]
# Out:
# /var/folders/bj/qp6k2wl11h5gpn8j4hg0tgf40000gn/T/ipykernel_47369/247178040.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["lemma_lang"]= df["SENSE_LEMMA"]+"_"+df["LANG_PRON"]

# %%
len(df)
# Out:
# 1980472

# %%
pron_folder = "../data/phon/preprocessed"

# %%
import glob, os

# %%
lemma_dict = {}
for file in glob.glob(f"{pron_folder}/*.tsv"):
    print(file)
    lang = os.path.basename(file).replace(".tsv", "")
    df_pron = pd.read_csv(file, sep="\t")
    
    for lemma, pron in zip(df_pron["lemma"], df_pron["pron"]):
        
        try:
            lemma = lemma.replace(" ", "_")
            lemma_dict[lemma+"_"+lang]=pron
        except Exception:
            print(lemma, lang)
# Out:
# ../data/phon/preprocessed/wau.tsv
# ../data/phon/preprocessed/nno.tsv
# ../data/phon/preprocessed/pjt.tsv
# ../data/phon/preprocessed/scn.tsv
# ../data/phon/preprocessed/slv.tsv
# ../data/phon/preprocessed/sme.tsv
# ../data/phon/preprocessed/chb.tsv
# ../data/phon/preprocessed/ary.tsv
# ../data/phon/preprocessed/ofs.tsv
# nan ofs
# ../data/phon/preprocessed/stq.tsv
# ../data/phon/preprocessed/dlm.tsv
# ../data/phon/preprocessed/huu.tsv
# ../data/phon/preprocessed/ces.tsv
# ../data/phon/preprocessed/zha.tsv
# ../data/phon/preprocessed/sco.tsv
# ../data/phon/preprocessed/lat.tsv
# ../data/phon/preprocessed/ppl.tsv
# ../data/phon/preprocessed/nci.tsv
# ../data/phon/preprocessed/nav.tsv
# ../data/phon/preprocessed/nld.tsv
# ../data/phon/preprocessed/yor.tsv
# ../data/phon/preprocessed/lwl.tsv
# ../data/phon/preprocessed/ban.tsv
# ../data/phon/preprocessed/lav.tsv
# ../data/phon/preprocessed/hts.tsv
# ../data/phon/preprocessed/mga.tsv
# ../data/phon/preprocessed/mfe.tsv
# ../data/phon/preprocessed/arz.tsv
# ../data/phon/preprocessed/dng.tsv
# ../data/phon/preprocessed/syc.tsv
# ../data/phon/preprocessed/dum.tsv
# ../data/phon/preprocessed/crx.tsv
# ../data/phon/preprocessed/osp.tsv
# ../data/phon/preprocessed/bod.tsv
# ../data/phon/preprocessed/khm.tsv
# ../data/phon/preprocessed/bak.tsv
# ../data/phon/preprocessed/lad.tsv
# ../data/phon/preprocessed/apw.tsv
# ../data/phon/preprocessed/msa.tsv
# ../data/phon/preprocessed/fao.tsv
# nan fao
# ../data/phon/preprocessed/haw.tsv
# ../data/phon/preprocessed/akk.tsv
# ../data/phon/preprocessed/crk.tsv
# ../data/phon/preprocessed/asm.tsv
# ../data/phon/preprocessed/che.tsv
# ../data/phon/preprocessed/tft.tsv
# ../data/phon/preprocessed/ceb.tsv
# ../data/phon/preprocessed/nya.tsv
# ../data/phon/preprocessed/yux.tsv
# ../data/phon/preprocessed/phl.tsv
# ../data/phon/preprocessed/nap.tsv
# ../data/phon/preprocessed/non.tsv
# ../data/phon/preprocessed/ido.tsv
# ../data/phon/preprocessed/lzz.tsv
# ../data/phon/preprocessed/egy.tsv
# ../data/phon/preprocessed/dan.tsv
# ../data/phon/preprocessed/mkd.tsv
# ../data/phon/preprocessed/hye.tsv
# ../data/phon/preprocessed/hau.tsv
# ../data/phon/preprocessed/tel.tsv
# ../data/phon/preprocessed/kik.tsv
# ../data/phon/preprocessed/bul.tsv
# ../data/phon/preprocessed/ltg.tsv
# ../data/phon/preprocessed/pol.tsv
# ../data/phon/preprocessed/pms.tsv
# ../data/phon/preprocessed/ewe.tsv
# ../data/phon/preprocessed/lij.tsv
# ../data/phon/preprocessed/ron.tsv
# ../data/phon/preprocessed/eng.tsv
# nan eng
# nan eng
# nan eng
# nan eng
# nan eng
# nan eng
# nan eng
# nan eng
# nan eng
# nan eng
# nan eng
# nan eng
# ../data/phon/preprocessed/cor.tsv
# ../data/phon/preprocessed/hin.tsv
# ../data/phon/preprocessed/jpn.tsv
# ../data/phon/preprocessed/srd.tsv
# ../data/phon/preprocessed/sqi.tsv
# ../data/phon/preprocessed/cos.tsv
# ../data/phon/preprocessed/tby.tsv
# ../data/phon/preprocessed/mlg.tsv
# ../data/phon/preprocessed/kmr.tsv
# nan kmr
# ../data/phon/preprocessed/kxd.tsv
# ../data/phon/preprocessed/yid.tsv
# ../data/phon/preprocessed/nhx.tsv
# ../data/phon/preprocessed/pox.tsv
# ../data/phon/preprocessed/ell.tsv
# ../data/phon/preprocessed/kas.tsv
# ../data/phon/preprocessed/ota.tsv
# ../data/phon/preprocessed/aze.tsv
# ../data/phon/preprocessed/cmn.tsv
# ../data/phon/preprocessed/tur.tsv
# ../data/phon/preprocessed/oci.tsv
# ../data/phon/preprocessed/xal.tsv
# ../data/phon/preprocessed/cop.tsv
# ../data/phon/preprocessed/div.tsv
# ../data/phon/preprocessed/deu.tsv
# nan deu
# nan deu
# nan deu
# ../data/phon/preprocessed/got.tsv
# ../data/phon/preprocessed/nhn.tsv
# ../data/phon/preprocessed/urd.tsv
# ../data/phon/preprocessed/pus.tsv
# ../data/phon/preprocessed/ayl.tsv
# ../data/phon/preprocessed/ton.tsv
# ../data/phon/preprocessed/mya.tsv
# ../data/phon/preprocessed/vol.tsv
# ../data/phon/preprocessed/amh.tsv
# ../data/phon/preprocessed/zza.tsv
# nan zza
# ../data/phon/preprocessed/izh.tsv
# ../data/phon/preprocessed/kok.tsv
# ../data/phon/preprocessed/lim.tsv
# ../data/phon/preprocessed/rup.tsv
# ../data/phon/preprocessed/gml.tsv
# ../data/phon/preprocessed/ita.tsv
# ../data/phon/preprocessed/ukr.tsv
# ../data/phon/preprocessed/guj.tsv
# ../data/phon/preprocessed/mlt.tsv
# ../data/phon/preprocessed/jje.tsv
# ../data/phon/preprocessed/fry.tsv
# ../data/phon/preprocessed/zul.tsv
# ../data/phon/preprocessed/cym.tsv
# ../data/phon/preprocessed/aot.tsv
# ../data/phon/preprocessed/ang.tsv
# nan ang
# ../data/phon/preprocessed/acw.tsv
# ../data/phon/preprocessed/tyv.tsv
# ../data/phon/preprocessed/tzm.tsv
# ../data/phon/preprocessed/fro.tsv
# ../data/phon/preprocessed/shn.tsv
# ../data/phon/preprocessed/mar.tsv
# ../data/phon/preprocessed/sga.tsv
# ../data/phon/preprocessed/mon.tsv
# ../data/phon/preprocessed/kat.tsv
# ../data/phon/preprocessed/nrf.tsv
# ../data/phon/preprocessed/bdq.tsv
# ../data/phon/preprocessed/kld.tsv
# ../data/phon/preprocessed/rus.tsv
# ../data/phon/preprocessed/wiy.tsv
# ../data/phon/preprocessed/pan.tsv
# ../data/phon/preprocessed/eus.tsv
# ../data/phon/preprocessed/urk.tsv
# ../data/phon/preprocessed/goh.tsv
# ../data/phon/preprocessed/por.tsv
# ../data/phon/preprocessed/lit.tsv
# ../data/phon/preprocessed/kor.tsv
# ../data/phon/preprocessed/kan.tsv
# ../data/phon/preprocessed/mah.tsv
# ../data/phon/preprocessed/aar.tsv
# ../data/phon/preprocessed/twf.tsv
# ../data/phon/preprocessed/ben.tsv
# ../data/phon/preprocessed/gle.tsv
# ../data/phon/preprocessed/iba.tsv
# ../data/phon/preprocessed/pbv.tsv
# ../data/phon/preprocessed/ett.tsv
# ../data/phon/preprocessed/glg.tsv
# ../data/phon/preprocessed/bre.tsv
# ../data/phon/preprocessed/bel.tsv
# ../data/phon/preprocessed/kaz.tsv
# ../data/phon/preprocessed/enm.tsv
# ../data/phon/preprocessed/gur.tsv
# ../data/phon/preprocessed/zom.tsv
# ../data/phon/preprocessed/cnk.tsv
# ../data/phon/preprocessed/sid.tsv
# ../data/phon/preprocessed/fra.tsv
# nan fra
# nan fra
# ../data/phon/preprocessed/mak.tsv
# ../data/phon/preprocessed/srn.tsv
# ../data/phon/preprocessed/olo.tsv
# ../data/phon/preprocessed/abk.tsv
# ../data/phon/preprocessed/hrx.tsv
# nan hrx
# ../data/phon/preprocessed/kal.tsv
# ../data/phon/preprocessed/liv.tsv
# ../data/phon/preprocessed/new.tsv
# ../data/phon/preprocessed/nds.tsv
# ../data/phon/preprocessed/ina.tsv
# ../data/phon/preprocessed/nhg.tsv
# ../data/phon/preprocessed/uig.tsv
# ../data/phon/preprocessed/kbd.tsv
# ../data/phon/preprocessed/dsb.tsv
# nan dsb
# ../data/phon/preprocessed/heb.tsv
# ../data/phon/preprocessed/fin.tsv
# ../data/phon/preprocessed/ale.tsv
# ../data/phon/preprocessed/frr.tsv
# ../data/phon/preprocessed/tam.tsv
# ../data/phon/preprocessed/mnw.tsv
# ../data/phon/preprocessed/ind.tsv
# ../data/phon/preprocessed/pcc.tsv
# ../data/phon/preprocessed/nep.tsv
# ../data/phon/preprocessed/gla.tsv
# ../data/phon/preprocessed/glv.tsv
# ../data/phon/preprocessed/lif.tsv
# ../data/phon/preprocessed/cbn.tsv
# ../data/phon/preprocessed/mww.tsv
# ../data/phon/preprocessed/tuk.tsv
# ../data/phon/preprocessed/spa.tsv
# ../data/phon/preprocessed/mal.tsv
# ../data/phon/preprocessed/cat.tsv
# nan cat
# ../data/phon/preprocessed/mnc.tsv
# ../data/phon/preprocessed/lsi.tsv
# ../data/phon/preprocessed/ilo.tsv
# ../data/phon/preprocessed/nob.tsv
# ../data/phon/preprocessed/krl.tsv
# ../data/phon/preprocessed/ycl.tsv
# ../data/phon/preprocessed/bcl.tsv
# ../data/phon/preprocessed/khb.tsv
# ../data/phon/preprocessed/blt.tsv
# ../data/phon/preprocessed/ast.tsv
# ../data/phon/preprocessed/jam.tsv
# ../data/phon/preprocessed/afb.tsv
# ../data/phon/preprocessed/tpw.tsv
# ../data/phon/preprocessed/mdf.tsv
# ../data/phon/preprocessed/ori.tsv
# ../data/phon/preprocessed/san.tsv
# ../data/phon/preprocessed/rgn.tsv
# ../data/phon/preprocessed/ybi.tsv
# ../data/phon/preprocessed/wlm.tsv
# ../data/phon/preprocessed/kir.tsv
# ../data/phon/preprocessed/mic.tsv
# ../data/phon/preprocessed/osx.tsv
# ../data/phon/preprocessed/slk.tsv
# ../data/phon/preprocessed/csb.tsv
# ../data/phon/preprocessed/mqs.tsv
# ../data/phon/preprocessed/sce.tsv
# ../data/phon/preprocessed/tgk.tsv
# ../data/phon/preprocessed/grc.tsv
# ../data/phon/preprocessed/pdc.tsv
# ../data/phon/preprocessed/isl.tsv
# ../data/phon/preprocessed/lmy.tsv
# ../data/phon/preprocessed/ara.tsv
# ../data/phon/preprocessed/ajp.tsv
# ../data/phon/preprocessed/hbs.tsv
# ../data/phon/preprocessed/swe.tsv
# ../data/phon/preprocessed/afr.tsv
# ../data/phon/preprocessed/dzo.tsv
# ../data/phon/preprocessed/okm.tsv
# ../data/phon/preprocessed/tha.tsv
# ../data/phon/preprocessed/sah.tsv
# ../data/phon/preprocessed/lmo.tsv
# ../data/phon/preprocessed/nan.tsv
# ../data/phon/preprocessed/ltz.tsv
# nan ltz
# ../data/phon/preprocessed/nor.tsv
# ../data/phon/preprocessed/kpv.tsv
# ../data/phon/preprocessed/gsw.tsv
# ../data/phon/preprocessed/tgl.tsv
# ../data/phon/preprocessed/ckb.tsv
# ../data/phon/preprocessed/syl.tsv
# ../data/phon/preprocessed/vie.tsv
# nan vie
# nan vie
# nan vie
# nan vie
# nan vie
# nan vie
# ../data/phon/preprocessed/fas.tsv
# ../data/phon/preprocessed/ady.tsv
# ../data/phon/preprocessed/xho.tsv
# ../data/phon/preprocessed/cho.tsv
# ../data/phon/preprocessed/arc.tsv
# ../data/phon/preprocessed/hun.tsv
# ../data/phon/preprocessed/lao.tsv
# ../data/phon/preprocessed/yue.tsv
# ../data/phon/preprocessed/epo.tsv
# ../data/phon/preprocessed/est.tsv
# ../data/phon/preprocessed/nmy.tsv

# %%
lemma_dict
# Out:
# {'agama_wau': 'a ɰ a m a',
#  'agapai_wau': 'a ɰ a p a ɪ',
#  'agatapai_wau': 'a ɰ a t a p a ɪ',
#  'ahala_wau': 'a h a l a',
#  'ahamaitsapai_wau': 'a h a m a ɪ t͡s a p a ɪ',
#  'ahatain_wau': 'a h a t a ĩ',
#  'aitsa_ha_wau': 'a ɪ t͡s a h a',
#  'aka_wau': 'a k a',
#  'akain_wau': 'a k a ĩ',
#  'akainxa_wau': 'a k a ĩ t j a',
#  'akamapai_wau': 'a k a m a p a ɪ',
#  'akitsatapai_wau': 'a k i t͡s a t a p a ɪ',
#  'akixekojatapai_wau': 'a k i t j ɛ k ɨ ʐ a t a p a ɪ',
#  'akiyuntuapa_wau': 'a k i j ũ t u a p a',
#  'akulukatapai_wau': 'a k u l u k a t a p a ɪ',
#  'amakanata_wau': 'a m a k a n a t a',
#  'amamitsapai_wau': 'a m a m i t͡s a p a ɪ',
#  'amapitsaitsapai_wau': 'a m a p i t͡s a ɪ t͡s a p a ɪ',
#  'aminya_wau': 'a m ĩ j a',
#  'amunaun_wau': 'a m u n ɐ̃ ʊ',
#  'anapi_wau': 'a n a p i',
#  'apaka_wau': 'a p a k a',
#  'apakata_wau': 'a p a k a t a',
#  'apiya_wau': 'a p i j a',
#  'apotapai_wau': 'a p ɨ t a p a ɪ',
#  'asatapai_wau': 'a s a t a p a ɪ',
#  'ate_wau': 'a t ɛ',
#  'atokapai_wau': 'a t ɨ k a p a ɪ',
#  'atso_wau': 'a t͡s ɨ',
#  'atsoke_wau': 'a t͡s ɨ k ɛ',
#  'atukutapai_wau': 'a t u k u t a p a ɪ',
#  'aunaki_wau': 'a ʊ n a k i',
#  'aunakitsapai_wau': 'a ʊ n a k i t͡s a p a ɪ',
#  'aupeki_wau': 'a ʊ p ɛ k i',
#  'aupepei_wau': 'a ʊ p ɛ p e ɪ',
#  'autu_wau': 'a ʊ t u',
#  'ayakatapai_wau': 'a j a k a t a p a ɪ',
#  'eejo_wau': 'ɛː ʐ ɨ',
#  'ehejepei_wau': 'ɛ h ɛ ʐ ɛ p e ɪ',
#  'ehen_wau': 'ɛ̃ h ɛ̃',
#  'ejekujata_wau': 'ɛ ʐ ɛ k u ʐ a t a',
#  'elelepei_wau': 'ɛ l ɛ l ɛ p e ɪ',
#  'epete_wau': 'ɛ p ɛ t ɛ',
#  'epi_wau': 'ɛ p i',
#  'etemepei_wau': 'ɛ t ɛ m ɛ p e ɪ',
#  'hain_wau': 'h a ĩ',
#  'hapari_wau': 'h a p a ɾ i',
#  'hauka_wau': 'h a ʊ k a',
#  'homakapai_wau': 'h ɨ m a k a p a ɪ',
#  'intsixupai_wau': 'ĩ t͡s i t j u p a ɪ',
#  'ipisulu_wau': 'i p i s u l u',
#  'ipisun_wau': 'i p i s ũ',
#  'irixulakuma_wau': 'i ɾ i t j u l a k u m a',
#  'isiki_wau': 'i s i k i',
#  'itseepu_wau': 'i t͡s ɛː p u',
#  'itseeputa_wau': 'i t͡s ɛː p u t a',
#  'itsenu_wau': 'i t͡s ɛ n u',
#  'iya_wau': 'i j a',
#  'iyepe_wau': 'i j ɛ p ɛ',
#  'ju_wau': 'ʐ u',
#  'kagapa_wau': 'k a ɰ a p a',
#  'kajutukalu_wau': 'k a ʂ u t u k a l u',
#  'kakaintsixupai_wau': 'k a k a ĩ t͡s i t j u p a ɪ',
#  'kalunti_wau': 'k a l ũ t i',
#  'kamalajo_wau': 'k a m a l a ʐ ɨ',
#  'kamani_wau': 'k a m a n i',
#  'kamaukula_wau': 'k a m a ʊ k u l a',
#  'kamaukulataputa_wau': 'k a m a ʊ k u l a t a p u t a',
#  'kamo_wau': 'k a m ɨ',
#  'kanai_wau': 'k a n a i',
#  'kapaka_wau': 'k a p a k a',
#  'kapojai_wau': 'k a p ɨ ʐ a ɪ',
#  'katapai_wau': 'k a t a p a ɪ',
#  'kehoto_wau': 'k ɛ h ɨ t ɨ',
#  'keweintsapai_wau': 'k ɛ w e ĩ t͡s a p a ɪ',
#  'keyeixapai_wau': 'k ɛ j ɛ ɪ t j a p a ɪ',
#  'kisuawakiya_wau': 'k i s u w a w a k i j a',
#  'kitsimain_wau': 'k i t͡s i m a ĩ',
#  'kixekojapai_wau': 'k i t j ɛ k ɨ ʐ a p a ɪ',
#  'kiyaga_wau': 'k i j a ɰ a',
#  'kiyankan_wau': 'k i j ã k ã',
#  'kuyekuyeju_wau': 'k u j ɛ k u j ɛ ʂ u',
#  'kwakwoho_wau': 'k w a k w ɨ h ɨ',
#  'mainki_wau': 'm a ĩ k i',
#  'mainxapai_wau': 'm a ĩ t j a p a ɪ',
#  'malaho_wau': 'm a l a h ɨ',
#  'mapa_wau': 'm a p a',
#  'mepiaunwaun_wau': 'm ɛ p i j ɐ̃ ʊ w ɐ̃ ʊ',
#  'mepiaunwaun_ikitsapa_wau': 'm ɛ p i j ɐ̃ ʊ w ɐ̃ ʊ i k i t͡s a p a',
#  'mepiaunwaun_wojoku_wau': 'm ɛ p i j ɐ̃ ʊ w ɐ̃ ʊ w ɨ ʂ ɨ k u',
#  'mepiaunwauntaputa_wau': 'm ɛ p i j ɐ̃ ʊ w ɐ̃ ʊ t a p u t a',
#  'mepiaunwaunwaka_wau': 'm ɛ p i j ɐ̃ ʊ w ɐ̃ ʊ w a k a',
#  'mepiaunwaunwakataputa_wau': 'm ɛ p i j ɐ̃ ʊ w ɐ̃ ʊ w a k a t a p u t a',
#  'metseepu_wau': 'm ɛ t͡s eː p u',
#  'meyeixapai_wau': 'm ɛ j ɛ ɪ t j a p a ɪ',
#  'meyeixaya_wau': 'm ɛ j ɛ ɪ t j a j a',
#  'minyulitai_wau': 'm ĩ j u l i t a ɪ',
#  'mohonjapai_wau': 'm ɨ̃ h ɨ̃ ʐ a p a ɪ',
#  'muinpai_wau': 'm u ĩ p a ɪ',
#  'natu_wau': 'n a t u',
#  'nejo_wau': 'n ɛ ʐ ɨ',
#  'nu_wau': 'n u',
#  'nutai_wau': 'n u t a ɪ',
#  'ogatakoja_wau': 'ɨ ɰ a t a k ɨ ʐ a',
#  'ohapa_wau': 'ɨ h a p a',
#  'ohapaitsa_wau': 'ɨ h a p a ɪ t͡s a',
#  'okaintsixu_wau': 'ɨ k a ĩ t͡s i t j u',
#  'okanu_wau': 'ɨ k a n u',
#  'okanupai_wau': 'ɨ k a n u p a ɪ',
#  'okiyuntuapitsana_wau': 'ɨ k i y ũ t u w a p i t͡s a n a',
#  'okupona_wau': 'ɨ k u p ɨ n a',
#  'omaluwaintsa_wau': 'ɨ m a l u w a ĩ t͡s a',
#  'onaatsa_wau': 'ɨ n aː t͡s a',
#  'onu_wau': 'ɨ n u',
#  'onuka_wau': 'ɨ n u k ə',
#  'onupapai_wau': 'ɨ n u p a p a ɪ',
#  'ooja_wau': 'ɨː ʐ a',
#  'opoku_wau': 'ɨ p ɨ k u',
#  'otowo_wau': 'ɨ t ɨ w ɨ',
#  'otukaka_wau': 'ɨ t u k a k a',
#  'oukapai_wau': 'ɨ u k a p a ɪ',
#  'painxanato_wau': 'p a ĩ t j a n a t ɨ',
#  'paunwaun_wau': 'p ɐ̃ ʊ w ɐ̃ ʊ',
#  'paunwaun_ikitsapa_wau': 'p ɐ̃ ʊ w ɐ̃ ʊ i k i t͡s a p a',
#  'paunwaun_wojoku_wau': 'p ɐ̃ ʊ w ɐ̃ ʊ w ɨ ʂ ɨ k u',
#  'paunwauntaputa_wau': 'p ɐ̃ ʊ w ɐ̃ ʊ t a p u t a',
#  'pitsu_wau': 'p i t͡s u',
#  'sekunya_wau': 's ɛ k ũ j a',
#  'suyumapai_wau': 's u j u m a p a ɪ',
#  'takapapai_wau': 't a k a p a p a ɪ',
#  'teme_wau': 't ɛ m ɛ',
#  'toneju_wau': 't ɨ n ɛ ʐ u',
#  'topoho_wau': 't ɨ p ɨ h ɨ',
#  'tya_wau': 't j a',
#  'ui_wau': 'u w i',
#  'ulepe_wau': 'u l ɛ p ɛ',
#  'uno_wau': 'ũ n ɨ',
#  'usixuwi_wau': 'u s i t j u w i',
#  'uuta_wau': 'uː t a',
#  'uwein_wau': 'u w e ĩ',
#  'waku_wau': 'w a k u',
#  'wauja_wau': 'w a ʊ ʐ a',
#  'wenekutaku_wau': 'w ɛ n ɛ k u t a k u',
#  'weruyapai_wau': 'w ɛ r u j a p a ɪ',
#  'yaka_wau': 'j a k a',
#  'yamukunauntope_wau': 'j a m u k u n ɐ̃ ʊ t ɨ p ɛ',
#  'yamukutai_wau': 'j a m u k u t a ɪ',
#  'yamukutopa_wau': 'j a m u k u t ɨ p a',
#  'yanumaka_wau': 'j a n u m a k a',
#  'yanumaka_kapala_wau': 'j a n u m a k a k a p a l a',
#  'yeyawa_wau': 'j e ɪ j a w a',
#  'yuta_wau': 'j u t a',
#  'a_nno': 'ɑː',
#  'ablegøyer_nno': 'ɑ b l ə ² ɡ œ ʏ ə r',
#  'abortiv_nno': 'ɑ b ɔ ʈ iː ʋ',
#  'acre_nno': 'æ ɪ k ə r',
#  'adel_nno': 'ɑː d ɛ l',
#  'adept_nno': 'ɑ d ɛ p t',
#  'adle_nno': '² ɑː d l ə',
#  'afrikansk_nno': 'ɑ f r i k ɑː n s k',
#  'aftan_nno': 'ɑ̂ f t ɑ n',
#  'age_nno': '² ɑː ɡ ə',
#  'agje_nno': '² ɑː j ə',
#  'agjen_nno': '² ɑː j ə n',
#  'agn_nno': 'ɑ ŋ n',
#  'agurktid_nno': 'ɑ ɡ ʉ ɾ k t iː',
#  'ake_nno': '² ɑː k ə',
#  'akjån_nno': '² ɑː ç oː n',
#  'akka_nno': 'ɑ k k ɑ',
#  'akke_nno': '² ɑ k k ə',
#  'aksel_nno': 'ɑ k s ɛ l',
#  'aksent_nno': 'ɑ k s ɒ ŋ',
#  'aktsam_nno': 'a k t s aː m',
#  'alaskar_nno': 'ɑ l ɑ s k ɑ ɾ',
#  'alaskisk_nno': 'ɑ l ɑ s k ɪ s k',
#  'alde_nno': '² ɑ l d ə',
#  'alder_nno': 'ɑ l d ɛ r',
#  'alfabet_nno': 'ɑ l f ɑ b eː t',
#  'alke_nno': '² ɑ l k ə',
#  'all_nno': 'ɑ lː',
#  'alle_nno': 'ɑ l l eː',
#  'altso_nno': 'ɑ l t s ʊ',
#  'altså_nno': 'ɑ l t s ɔ',
#  'alvorleg_nno': 'ɑ l ʋ oː r l ɛ ɡ',
#  'amerikanar_nno': 'aː m ə r i k aː n aː r',
#  'ammetåke_nno': '² ɑ m m ə t oː k ə',
#  'ananas_nno': 'ɑ nː ɑ n ɑ s',
#  'and_nno': 'ɑ nː',
#  'andektig_nno': 'ɑ n d ɛ k t ɪ',
#  'andlet_nno': '² ɑ n l eː t',
#  'ane_nno': 'ɑː n ə',
#  'anga_nno': '² ɑ ŋ ŋ ɑ',
#  'angar_nno': '² ɑ ŋ ŋ ɑ r',
#  'ange_nno': '² ɑ ŋ ŋ ə',
#  'angje_nno': '² ɑ ɲ j ə',
#  'angjen_nno': '² ɑ ŋ j ə n',
#  'angripa_nno': 'a n ɡ r iː p a',
#  'ankel_nno': '² ɑ ŋ k ə l',
#  'annan_nno': '² ɑ nː ɑ n',
#  'anten_nno': 'a n t ɛ n',
#  'antibiotikum_nno': 'a n t i b i uː t i k ʉ m',
#  'apokalypse_nno': 'a p u k a l y p s ə',
#  'argument_nno': 'ɑ r ɡ ʉ m ɛ n t',
#  'arkja_nno': 'ɑ r ç ɑ',
#  'arm_nno': 'ɑ r m',
#  'arme_nno': 'ɑ r m eː',
#  'ase_nno': '² ɑː s ə',
#  'ask_nno': 'ɑ s k',
#  'at_nno': 'ɑ tː',
#  'atal_nno': '² ɑː t ɑ l',
#  'ateist_nno': 'ɑ t ə ɪ s t',
#  'atomvåpen_nno': 'aː t uː m ʋ ɒː p ɛ n',
#  'attanfor_nno': 'a t a n f ɔ r',
#  'atten_nno': '² ɑ t t ə n',
#  'atter_nno': 'ɑ tː ɛ r',
#  'attom_nno': '² a tː ʊ m',
#  'aud_nno': 'æ ʉ',
#  'auga_nno': '² œ ʉ̯ ɡ ɑ',
#  'auge_nno': '² æ ʉ̯ ɡ ə',
#  'augestikkar_nno': 'ø ʉ ɡ ə s t i k a r',
#  'auget_nno': '² æ ʉ̯ ɡ ə',
#  'auka_nno': 'ø ʉ k a',
#  'auke_nno': 'ø u k ə',
#  'aur_nno': 'œ ʉ̯ r',
#  'austover_nno': 'ø ʉ s t ɔː ʋ ɛ r',
#  'av_nno': 'ɑː ʋ',
#  'avgjera_nno': 'ɑː ʋ j eː r ɑ',
#  'avhengig_nno': 'aː ʋ h e ŋ ɡ i',
#  'avhoppar_nno': 'aː ʋ h ɔ p a r',
#  'avis_nno': 'ɑ ʋ iː s',
#  'avisa_nno': 'ɑ ʋ iː s ɑ',
#  'avisene_nno': 'ɑ ʋ iː s n̩ ə',
#  'aviser_nno': 'ɑ ʋ iː s ə r',
#  'avkastning_nno': 'aː ʋ k a s t n i ŋ ɡ',
#  'avl_nno': 'ɑ ʋ l',
#  'avla_nno': 'a ʋ l a',
#  'avstand_nno': 'aː ʋ s t a n',
#  'b_nno': 'b eː',
#  'bacon_nno': 'b æ j k ə n',
#  'bad_nno': 'b ɑː d',
#  'bakbord_nno': 'b aː k b uʷː ɾ',
#  'bakkje_nno': '² b ɑ ç ç ə n',
#  'bakkjen_nno': '² b ɑ ç ç ə n',
#  'banan_nno': 'b ɑ n aː n',
#  'bank_nno': 'b ɑ ŋ k',
#  'banne_nno': '² b ɑ n n ə',
#  'bannlyse_nno': 'b ɑ nː ² l yː s ə',
#  'bar_nno': 'b ɑː r',
#  'barkje_nno': '² b ɑ r ç ə',
#  'barkjen_nno': '² b ɑ r ç ə n',
#  'barn_nno': 'b ɑː r n',
#  'barnehage_nno': 'b ɑː ɳ ə h ɑː ɡ ə',
#  'barnsleg_nno': '² b ɑː r n s l ɛ',
#  'bart_nno': 'b ɑ ʈ',
#  'be_nno': 'b eː',
#  'begge_nno': 'b ɛ ɡ ə',
#  'behageleg_nno': 'b ə h aː ɡ ə l eː ɡ',
#  'behalda_nno': 'b eː h a l d a',
#  'beita_nno': '² b æ ɪ t ɑ',
#  'beite_nno': 'b ɛ i t ə',
#  'bekk_nno': 'b ɛ kː',
#  'bekken_nno': 'b ɛ kː ə n',
#  'bendelorm_nno': 'b ɛ n d ə l ɔ r m',
#  'benektelse_nno': 'b ə n ɛ k t ə l s ə',
#  'bere_nno': '² b eː r ə',
#  'berget_nno': 'b ɛ r ʝ ə',
#  'bergmann_nno': 'b æ r ɡ m ɑ n',
#  'bergta_nno': 'b ɛ r ɡ t a',
#  'berre_nno': '² b ɛ rː ə',
#  'besøk_nno': 'b eː s øː k',
#  'besøkja_nno': 'b eː s øː ç a',
#  'bety_nno': 'b eː t y',
#  'bever_nno': 'b eː ʋ ɛ r',
#  'biblioteka_nno': 'b ɪ b l j u t eː k ɑ',
#  'bide_nno': '² b iː d ə',
#  'bie_nno': '² b iː ə',
#  'bil_nno': 'b iː l',
#  'bilda_nno': 'b ɪ l d ɑ',
#  'bilde_nno': 'b ɪ l d ə',
#  'bildet_nno': 'b ɪ l d ə',
#  'binær_nno': 'b ɪ n æː ɾ',
#  'biti_nno': '² b iː t ɪ',
#  'bjørgvin_nno': '² b j œ rˠ ɡ ʋ ɪ n',
#  'bjørka_nno': '² b j œ r k ɑ',
#  'blant_nno': 'b l ɑ n t',
#  'blemme_nno': 'b l ɛ m m ə',
#  'bli_nno': 'b l iː',
#  'blod_nno': 'b ɽ uː',
#  'blodskam_nno': 'b l uː s k a m',
#  'blomkål_nno': 'b l u m k ɒː l',
#  'blåkval_nno': '² b ɽ ɔː k ʋ ɑː ɽ',
#  'blåmeis_nno': '² b l oː m æ ɪ s',
#  'bløffe_nno': '² b l œ f f ə',
#  'bod_nno': 'b ɔː d',
#  'boen_nno': '² b uː ə n',
#  'bog_nno': 'b uː ɡ',
#  'bogjå_nno': 'b uː j o',
#  'bokjå_nno': 'b uː ç o',
#  'bokstav_nno': 'b ʊ k s t ɑː ʋ',
#  'bokstavleg_nno': 'b uː k s t aː ʋ l eː ɡ',
#  'bol_nno': 'b uː ɽ',
#  'boms_nno': 'b ʊ m s',
#  'bon_nno': 'b uː n',
#  'bona_nno': '² b uː n ɑ',
#  'bonde_nno': '² b ʊ nː ə',
#  'bongotromme_nno': 'b ʊ ŋ ɡ ʊ t ɾ ʊ m m ə',
#  'boni_nno': 'b uː n ɪ',
#  'bonom_nno': '² b uː n ʊ m',
#  'borgarleg_nno': 'b ɔ r ɡ aː r l eː ɡ',
#  'borkjen_nno': 'b ɔ r ç ə n',
#  'borte_nno': '² b ʊ r t ə',
#  'bortkasta_nno': 'b ʊ r t k a s t a',
#  'bos_nno': 'b oː s',
#  'boss_nno': 'b ɔ sː',
#  'braud_nno': 'b r æ ʉː',
#  'breiflabb_nno': '² b r æ ɪ f l ɑ b',
#  'brek_nno': 'b r eː k',
#  'breka_nno': '² b r eː k ɑ',
#  'breke_nno': '² b r eː k ə',
#  'brekja_nno': '² b r eː ç ɑ',
#  'brekje_nno': '² b r eː ç ə',
#  'brekkjern_nno': 'b ɾ ɛ k j æː ɳ',
#  'brekt_nno': 'b r ɛ k t',
#  'brekte_nno': '² b r ɛ k t ə',
#  'brenna_nno': 'b r ɛ n a',
#  'brennmanet_nno': 'b r ɛ n m aː n eː t',
#  'brev_nno': 'b r eː ʋ',
#  'brok_nno': 'b r uː k',
#  'brokkoli_nno': 'b r ɔ k ɔː l i',
#  'bronse_nno': 'b r ɔ n s ə',
#  'bror_nno': 'b r uː r',
#  'brosme_nno': '² b r ɔ s m ə',
#  'brotsverk_nno': 'b r ɔː t s v ɛ r k',
#  'bru_nno': 'b r ʉː',
#  'bruna_nno': '² b r ʉ n a',
#  'bruni_nno': 'b r ʉ n ɪ',
#  'bryllaup_nno': 'b r y l ø ʉ p',
#  'bråket_nno': '² b r oː k ɛ t',
#  'brød_nno': 'b r øː',
#  'brødskive_nno': '² b r øː ʃ iː ʋ ə',
#  'brønn_nno': 'b r ʉ nː',
#  'bu_nno': 'b ʉː',
#  'buddhist_nno': 'b ʉ d ɪ s t',
#  'buddhisten_nno': 'b ʉ d ɪ s t n̩',
#  'bukse_nno': '² b ʊ k s ə',
#  'bunad_nno': '² b ʉː n ɑ d',
#  'burka_nno': 'b ʉ r k ɑ',
#  'by_nno': 'b yː',
#  'bye_nno': '² b yː ə',
#  'byggja_nno': '² b ʏ ʝː ɑ',
#  'byksa_nno': '² b ʏ k s ɑ',
#  'bylgje_nno': '² b ʏ l j ə',
#  'byrja_nno': '² b ʏ r j ɑ',
#  'bystat_nno': 'b yː s t aː t',
#  'båe_nno': 'b ɒ ə',
#  'bån_nno': 'b oː n',
#  'båna_nno': 'b oː n ɑ',
#  'bånet_nno': 'b oː n ə',
#  'båra_nno': '² b oː r ə',
#  'bær_nno': 'b æː r',
#  'bæra_nno': '² b æː r ɑ',
#  'bæsje_nno': 'b æ ʃː ə',
#  'bøle_nno': '² b øː ɽ ə',
#  'bønn_nno': 'b œ n',
#  'bønner_nno': '² b œ n ə r',
#  'bør_nno': 'b øː ɽ',
#  'bøya_nno': '² b œ ʏ ɑ',
#  'casane_nno': '² k ɛ ɪ̯ s ɑ n ə',
#  'casar_nno': '² k ɛ ɪ̯ s ɑ r',
#  'case_nno': 'k ɛ ɪ̯ s',
#  'casen_nno': 'k ɛ ɪ̯ s ə n',
#  'caset_nno': 'k ɛ ɪ̯ s ə',
#  'cellofan_nno': 's ɛ l l ʊ f ɑː n',
#  'chat_nno': 't͡ʃ æ tː',
#  'chattar_nno': '² t͡ʃ æ tː ɑ r',
#  'chatte_nno': '² t͡ʃ æ tː ə',
#  'cykel_nno': 's yː k ə l',
#  'cymbal_nno': 's ʏ m b ɑː l',
#  'cymbel_nno': 's ʏ m b ə l',
#  'd_nno': 'd eː',
#  'da_nno': 'd ɑː',
#  'daa_nno': 'd oː',
#  'dag_nno': 'd ɑː ɡ',
#  'dagjen_nno': 'd ɑː j ə n',
#  'dane_nno': '² d ɑː n ə',
#  'datamus_nno': 'd aː t ɑ m ʉʷː s',
#  'dataspel_nno': 'd aː t a s p eː l',
#  'dataspeling_nno': 'd aː t a s p eː l i ŋ ɡ',
#  'de_nno': 'd iː',
#  'definera_nno': 'd ə f i n eː r a',
#  'definisjon_nno': 'd ə f i n i ʃ uː n',
#  'deg_nno': 'd eː ɡ',
#  'dei_nno': 'd æ ɪ',
#  'deig_nno': 'd ɛ i ɡ',
#  'deim_nno': 'd æ ɪ̯ m',
#  'deira_nno': '² d æ ɪ r ɑ',
#  'deker_nno': 'd eː k ə r',
#  'dekkja_nno': 'd ɛ ç a',
#  'del_nno': 'd eː l',
#  'den_nno': 'd ɛ nː',
#  'deretter_nno': 'd ɛ r ɛ t ɛ r',
#  'dermed_nno': 'd ɛ r m ə',
#  'derre_nno': 'd æ r r ə',
#  'dess_nno': 'd ɛ sː',
#  'dessutan_nno': 'd ɛ sː ʉ t ɑ n',
#  'det_nno': 'd eː',
#  'detta_nno': '² d ɛ tː ɑ',
#  'di_nno': 'd iː',
#  'dialyse_nno': 'd ɪ ɑ ² l yː s ə',
#  'dime_nno': 'd ɑ ɪ̯ m',
#  'dimed_nno': 'd iː m e',
#  'dimen_nno': 'd ɑ ɪ̯ m ə n',
#  'dimes_nno': 'd ɑ ɪ̯ m s',
#  'din_nno': 'd i n',
#  'dine_nno': 'd iː n ə',
#  'diskotek_nno': 'd ɪ s k ʊ t eː k',
#  'ditt_nno': 'd i t',
#  'diva_nno': 'd iː ʋ ɑ',
#  'djerv_nno': 'j ɛ r ʋ',
#  'do_nno': 'd oː',
#  'dokkas_nno': 'd ɔ k k ɑ s',
#  'dokker_nno': '² d ɔ k k ə r',
#  'dokument_nno': 'd ʊ k ʉ m ɛ n t',
#  'dovendyr_nno': 'd oː ʋ ə n d yː ɾ',
#  'drag_nno': 'd r ɑː ɡ',
#  'drama_nno': 'd r ɑː m ɑ',
#  'drammen_nno': 'd r a mː ə n',
#  'dramn_nno': 'd r a mː n̩',
#  'dregi_nno': '² d r eː ɡ ɪ',
#  'dreker_nno': 'd r eː k ə r',
#  'drikke_nno': '² d r ɪ kː ə',
#  'drone_nno': 'd r uː n ə',
#  'drosje_nno': 'd ɾ ɔʷ ʂ ə',
#  'dryle_nno': '² d ɾ yː l ə',
#  'drypa_nno': '² d r yː p ɑ',
#  'dræker_nno': 'd r eː k ə r',
#  'du_nno': 'd ʉː',
#  'duga_nno': 'd ʉː ɡ a',
#  'duggul_nno': '² d ʉ ɡ ɡ ʉ ɽ',
#  'dugul_nno': '² d ʉː ɡ ʉ ɽ',
#  'dugurd_nno': '² d ʉː ɡ ʉ ɽ',
#  'dumming_nno': 'd ʊ m m ɪ ŋ',
#  'dunge_nno': '² d ʊ ŋː ə',
#  'dvd_nno': 'd eː ʋ ə d eː',
#  'dvelja_nno': '² d ʋ ɛ l j ɑ',
#  'dvergplanet_nno': 'd ʋ ɛ r ɡ p l aː n eː t',
#  'dykk_nno': 'd ʏ kː',
#  'dysleksi_nno': 'd ʏ s l ɛ k s iː',
#  'då_nno': 'd oː',
#  'dår_nno': 'd oː r',
#  'dått_nno': 'd ɔ tː',
#  'døgn_nno': 'd œ ŋ n',
#  'døkk_nno': 'd œ kː',
#  'dølja_nno': '² d œ l j ɑ',
#  'døyande_nno': 'd ø y a n d ə',
#  'e_nno': 'ɛ',
#  'edderkopp_nno': 'ɛ d ə ɾ k ɔ p',
#  'eg_nno': 'eː ɡ',
#  'egg_nno': 'ɛ ɡː',
#  'ei_nno': 'æ ɪ̯',
#  'eid_nno': 'æ ɪ̯ d',
#  'eika_nno': 'æ ɪ k ɑ',
#  'ein_nno': 'æ ɪ̯ n',
#  'einannan_nno': 'ɛ i n a n a n',
#  'eineståande_nno': 'ɛ iː n ə s t ɒ a n d ə',
#  'eingong_nno': 'ɛ i n ɡ ɔ ŋ ɡ',
#  'einherje_nno': '² æ ɪ̯ n h æ ɾ j ə',
#  'einig_nno': '² æ ɪ n ɪ',
#  'einskap_nno': 'ɛ i n s k aː p',
#  'eiste_nno': '² æ ɪ̯ s t ə',
#  'eiter_nno': 'æ ɪ̯ t ə r',
#  'eiteret_nno': 'æ ɪ̯ t ə r ə',
#  'eitra_nno': 'æ ɪ̯ t r ɑ',
#  'eitret_nno': 'æ ɪ̯ t r ə',
#  'eitri_nno': 'æ ɪ̯ t r ɪ',
#  'ekorn_nno': 'ɛ kː ʊ r n',
#  'eksplodera_nno': 'ɛ k s p l uː d eː r a',
#  'ekstrem_nno': 'ɛ k s t r eː m',
#  'ekstremist_nno': 'ɛ k s t r e m i s t',
#  'ekstremt_nno': 'ɛ k s t r eː m t',
#  'ekteskap_nno': '² ɛ k t ə s k ɑː p',
#  'el_nno': 'eː l',
#  'elbil_nno': 'ɛ l b iː l',
#  'elev_nno': 'ɛ l eː ʋ',
#  'elg_nno': 'ɛ l ɡ',
#  'eliminera_nno': 'eː l i m i n eː r a',
#  'endåtil_nno': '² ɛ n d ɔ t ɪ lː',
#  'eng_nno': 'ɛ ŋː',
#  'engsteleg_nno': 'ɛ ŋ ɡ s t ə l eː ɡ',
#  'enorm_nno': 'eː n ɔ r m',
#  'enormt_nno': 'eː n ɔ r m t',
#  'enquête_nno': 'ɛ ŋ k eː t',
#  'eplepai_nno': 'ɛ p l ə p ɑ ɪ̯',
#  'er_nno': 'æː r',
#  'erfaring_nno': 'ɛ r f aː r i ŋ ɡ',
#  'erklæring_nno': 'æ ɾ k l æː ɾ ɪ ŋ',
#  'erobra_nno': 'eː r uː b r a',
#  'ert_nno': 'æ ʈː',
#  'ertene_nno': 'ɛ r t ə n ə',
#  'erter_nno': 'ɛ r t ə r',
#  'ertra_nno': 'ɛ r t r ɑ',
#  'eta_nno': '² eː t ɑ',
#  'etikk_nno': 'ɛ t ɪ kː',
#  'etter_nno': '² ɛ tː ɛ r',
#  'etterpå_nno': '² ɛ tː ɛ r p oː',
#  'fa_nno': 'f ɑː',
#  'fable_nno': 'f ɑː b l ə',
#  'fader_nno': '² f ɑː d ɛ r',
#  'fagidiot_nno': 'f aː ɡ ɪ d ɪ̯ u͍ː t',
#  'fakta_nno': '² f ɑ k t ɑ',
#  'faktisk_nno': 'f a k t i s k',
#  'falkeblikk_nno': 'f a l k ə b l i k',
#  'falkjen_nno': 'f ɑ l ç ə n',
#  'fall_nno': 'f ɑ lː',
#  'fallskjermhopping_nno': 'f ɑ l ʂ æ ɾ m h ɔ p p ɪ ŋ',
#  'fan_nno': 'f æ n',
#  'fange_nno': '² f ɑ ŋː ə',
#  'fanteri_nno': 'f a n t əː r i',
#  'far_nno': 'f ɑː r',
#  'farar_nno': 'f ɑː r ɑː r',
#  'faren_nno': '² f ɑː r n̩',
#  'farge_nno': '² f ɑ r ɡ ə',
#  'fasan_nno': 'f ɑ s aː n',
#  'fasinera_nno': 'f a s iː n eː r a',
#  'fasinerande_nno': 'f a s iː n eː r a n ə',
#  'fat_nno': 'f ɑː t',
#  'fata_nno': '² f ɑː t ɑ',
#  'fegge_nno': '² f ɛ ɡː ə',
#  'feira_nno': 'f ɛ iː r a',
#  'feita_nno': '² f æ ɪ̯ t ɑ',
#  'fele_nno': 'f eː l ə',
#  'felle_nno': '² f ɛ lː ə',
#  'femling_nno': 'f ɛ m l i ŋ ɡ',
#  'fennek_nno': 'f ɛ n n ə k',
#  'fenner_nno': 'f ɛ n n ə r',
#  'ferdamål_nno': 'f ɛ r d a m ɒː l',
#  'ferie_nno': 'f eː r j ə',
#  'ferje_nno': '² f ɛ r j ə',
#  'festning_nno': '² f ɛ s t n ɪ ŋ',
#  'fil_nno': 'f iː l',
#  'filar_nno': '² f iː l ɑ r',
#  'filen_nno': '² f iː ɳ̩',
#  'filleonkel_nno': 'f i lː ə u ŋ k ə l',
#  'fillerista_nno': 'f ɪ l ə r i s t a',
#  'filletante_nno': 'f i lː ə t a n t ə',
#  'fina_nno': '² f iː n ɑ',
#  'fingre_nno': '² f ɪ ŋ r ə',
#  'finna_nno': '² f ɪ nː ɑ',
#  'finnast_nno': '² f ɪ nː ɑ s t',
#  'fire_nno': 'f iː ɾ ə',
#  'firling_nno': 'f iː r l i ŋ ɡ',
#  'fisi_nno': '² f iː s ɪ',
#  'fivel_nno': '² f iː ʋ ə l',
#  'fjellrev_nno': '² f j ɛ l r eː v',
#  'fjerna_nno': 'f j ɛ r n a',
#  'fjernsyn_nno': 'f j ɛ r n s yː n',
#  'fjona_nno': '² f j uː n ɑ',
#  'fjonet_nno': '² f j uː n ə t',
#  'fjord_nno': 'f j uː r',
#  'fjorår_nno': 'f j uː r ɒː r',
#  'fjære_nno': 'f j æː ɾ ə',
#  'fjøl_nno': 'f j øʷː l',
#  'fjør_nno': 'f j øː r',
#  'fjøs_nno': 'f j øː s',
#  'flagg_nno': 'f l a ɡ',
#  'flaske_nno': '² f l a s k ə',
#  'flaum_nno': 'f l æ ʉ m',
#  'flege_nno': '² f ɽ eː ɡ ə',
#  'fleinsopp_nno': 'f l ɛ i n s ɔ p',
#  'fleire_nno': '² f l æ ɪ r ɛ',
#  'fleirtal_nno': 'f l æ ɪ r t ɑː l',
#  'flekk_nno': 'f l ɛ kː',
#  'fles_nno': 'f l eː s',
#  'fli_nno': 'f l iː',
#  'flo_nno': 'f l uː',
#  'flokete_nno': '² f l uː k ɛ t ə',
#  'flu_nno': 'f l ʉː',
#  'flua_nno': '² f l ʉː ɑ',
#  'fluar_nno': '² f l ʉː ɑ r',
#  'flue_nno': '² f l ʉː ə',
#  'flui_nno': 'f l ʉː ɪ',
#  'fly_nno': 'f l yː',
#  'flyga_nno': '² f l yː ɡ ɑ',
#  'flykta_nno': 'f l y k t a',
#  'flyktning_nno': 'f l y k t n i ŋ ɡ',
#  'flå_nno': 'f ɽ oː',
#  'flåte_nno': 'f ɽ oː t ə',
#  'flått_nno': 'f l ɔ t',
#  'fløyte_nno': '² f l œ ʏ t ə',
#  'fniset_nno': '² f n iː s ə t',
#  'fokk_nno': 'f ɔ kː',
#  'folka_nno': '² f ɔ l k ɑ',
#  'folket_nno': '² f ɔ l k ɛ t',
#  'folkje_nno': 'f ɔ l ç ə',
#  'folkjet_nno': 'f ɔ l ç ə',
#  'folkjo_nno': 'f ɔ l ç ʊ',
#  'folkjå_nno': 'f ɔ l ç o',
#  'fomle_nno': '² f ʊ m l ə',
#  'fomlen_nno': '² f ʊ m l ə n',
#  'fomlet_nno': '² f ʊ m l ɛ t',
#  'fomlete_nno': '² f ʊ m l ɛ t ə',
#  'fommel_nno': 'f ʊ m m ə l',
#  'fommelen_nno': 'f ʊ m m ə l ə n',
#  'fommelet_nno': 'f ʊ m m ə l ə',
#  'fonn_nno': 'f ɔ nː',
#  'for_nno': 'f ɔ rː',
#  'forakte_nno': 'f ɔ ɾ ɑ̀ k t ə',
#  'forbløffa_nno': 'f ɔ r b l ø f a',
#  'forbløffande_nno': 'f ɔ r b l ø f a n ə',
#  'forelder_nno': 'f ɔ r ɛ l d ɛ r',
#  'forfallen_nno': 'f ɔ r f ɑ lː n̩',
#  'forkasta_nno': 'f ɔ r k a s t a',
#  'formål_nno': 'f ɔ r m ɒː l',
#  'fornøgd_nno': 'f ɔ r n œ ɡ d',
#  'forsiktig_nno': 'f ɔ r s i k t i ɡ',
#  'forsvar_nno': 'f ɔ r s v ɑː r',
#  'forsvara_nno': 'f ɔ r s v aː r a',
#  'forsøk_nno': 'f ɔ r s øː k',
#  'fort_nno': 'f ɔ r t',
#  'fortena_nno': 'f ɔ r t eː n ɑ',
#  'fortid_nno': 'f ɔ r t iː',
#  'forvirra_nno': 'f ɔ r v i r a',
#  'foss_nno': 'f ɔ sː',
#  'framand_nno': 'f r aː m a n d',
#  'framdrift_nno': 'f r a m d r i f t',
#  'framfor_nno': '² f r ɑ m f ɔ r',
#  'framføre_nno': 'f r ɑ m f øː r ə',
#  'fransk_nno': 'f r a n s k',
#  'franske_nno': 'f r a n s k ə',
#  'fredeleg_nno': 'f r eː d e l eː ɡ',
#  'fredsdue_nno': 'f r eː d s d ʉ ə',
#  'fremja_nno': 'f r ɛ m j a',
#  'fremre_nno': '² f r ɛ m r ə',
#  'fri_nno': 'f r iː',
#  'frilans_nno': 'f r iː l ɑ n s',
#  'frilansar_nno': 'f r iː l ɑ n s ɑ r',
#  'fru_nno': 'f r ʉː',
#  'frykt_nno': 'f r y k t',
#  'frykteleg_nno': 'f r y k t ə l eː ɡ',
#  'fryser_nno': '² f r yː s ə r',
#  'frysning_nno': 'f ɾ ŷː s n ɪ ŋ',
#  'fråssar_nno': '² f r ɔ s s ɑ r',
#  'fråtsar_nno': '² f r ɔ t s ɑ r',
#  'fråtse_nno': '² f r ɔ t s ə',
#  'frøya_nno': '² f r œ ʏ ɑ',
#  'fugleinfluensa_nno': 'f ʉ ɡ l ə i n f l ʉ ə n s a',
#  'fumla_nno': '² f ʊ m l ɑ',
#  'fumle_nno': '² f ʊ m l ə',
#  'fumlen_nno': '² f ʊ m l ə n',
#  'fumlet_nno': '² f ʊ m l ɛ t',
#  'fumli_nno': '² f ʊ m l ɪ',
#  'fummel_nno': 'f ʊ m m ə l',
#  'fummelen_nno': 'f ʊ m m ə l ə n',
#  'fummelet_nno': 'f ʊ m m ə l ə',
#  'fundamentalist_nno': 'f ʉ n d a m ɛ n t a l i s t',
#  'furu_nno': '² f ʉː r ʉ',
#  'fyka_nno': '² f yː k ɑ',
#  'fylgja_nno': '² f ʏ l j ɑ',
#  'fyr_nno': 'f yː r',
#  'få_nno': 'f oː',
#  'fårikål_nno': 'f oʷː ɾ ɪ k ɔʷ l',
#  'føra_nno': '² f øː r ɑ',
#  'føre_nno': 'f øː r ə',
#  'førebels_nno': 'f øː r ə b eː l s',
#  'førebu_nno': 'f øː r eː b ʉː',
#  'førelegg_nno': 'f ø̂ː ɾ ə l ɛ ɡ',
#  'føremon_nno': '² f øː r ə m uː n',
#  'føremål_nno': 'f øː r ə m ɒː l',
#  'føyr_nno': 'f œ ʏ̯ r',
#  'føyra_nno': '² f œ ʏ̯ r ɑ',
#  'føyre_nno': '² f œ ʏ̯ r ə',
#  'galt_nno': 'ɡ ɑ l t',
#  'galtar_nno': '² ɡ ɑ l t ɑ r',
#  'galte_nno': '² ɡ ɑ l t ə',
#  'galten_nno': 'ɡ ɑ l t n̩',
#  'gamal_nno': '² ɡ ɑː m ɑ l',
#  'gammal_nno': '² ɡ ɑ mː ɑ l',
#  'gapet_nno': 'ɡ ɑː p ə',
#  'gard_nno': 'ɡ ɑː ɽ',
#  'garn_nno': 'ɡ a ʁ n',
#  'gasspedal_nno': 'ɡ a s p eː d aː l',
#  'gatekjøken_nno': 'ɡ aː t ə ç øː k ə n',
#  'gatekjøkken_nno': 'ɡ aː t ə ç œ k ə n',
#  'gauk_nno': 'ɡ æ ʉ k',
#  'gaukjen_nno': 'ɡ œ ʉ̯ ç ə n',
#  'gaule_nno': 'ɡ æ u̯ l ə',
#  'gaum_nno': 'ɡ ø ʉ m',
#  'geil_nno': 'j æ ɪ̯ l',
#  'geila_nno': '² j æ ɪ̯ l ɑ',
#  'geile_nno': '² j æ ɪ̯ l ə',
#  'geilen_nno': '² j æ ɪ̯ l n̩',
#  'geiler_nno': '² j æ ɪ̯ l ə r',
#  'geili_nno': 'j æ ɪ̯ l ɪ',
#  'geir_nno': 'j æ ɪ̯ r',
#  'geiren_nno': 'j æ ɪ̯ ŋ̩',
#  'geiter_nno': 'j æ ɪ̯ t ə r',
#  'generasjon_nno': 'ɡ e n eː r a ʃ uː n',
#  'gild_nno': 'j ɪ lː',
#  'gilda_nno': '² j ɪ l d ɑ',
#  'gildar_nno': '² j ɪ lː ɑ r',
#  'gilde_nno': '² j ɪ lː ə',
#  'gildet_nno': '² j ɪ l d ə',
#  'gildra_nno': '² j ɪ l d r ɑ',
#  'gimmer_nno': 'j ɪ mː ɛ r',
#  'giratar_nno': 'ʃ ɪ r ɑ t ɑː r',
#  'gissel_nno': 'ɡ ɪ s s ə l',
#  'gisseltakar_nno': 'ɡ i s ə l t aː k aː r',
#  'gje_nno': 'j eː',
#  'gjennomføra_nno': 'j ɛ n u m f øː r a',
#  'gjennomsnittsfart_nno': 'j ɛ n n ʊ m s n ɪ t s f ɑ ʈ',
#  'gjera_nno': '² j eː r ɑ',
#  'gjerne_nno': '² j ɛ r n ə',
#  'gjerningsmann_nno': 'j e r n i ŋ ɡ s m a n',
#  'gjester_nno': '² j ɛ s t ə r',
#  'gjorde_nno': '² j uː ɽ ə',
#  'gjæv_nno': 'j eː ʋ',
#  'gjø_nno': 'j øː',
#  'gjøde_nno': 'j øː d ə',
#  'gjørme_nno': 'j ø r m ə',
#  'glas_nno': 'ɡ l ɑː s',
#  'glasmanet_nno': 'ɡ l aː s m aː n eː t',
#  'glimt_nno': 'ɡ l ɪ m t',
#  'glimtar_nno': '² ɡ l ɪ m t ɑ r',
#  'gloret_nno': 'ɡ l uː r ə',
#  'glymja_nno': '² ɡ l ʏ m j ɑ',
#  'glymje_nno': '² ɡ l ʏ m j ə',
#  'gnik_nno': 'ɡ n iː k',
#  'gnika_nno': '² ɡ n ɪ k k ɑ',
#  'gniken_nno': 'ɡ n iː k ə n',
#  'gniki_nno': '² ɡ n iː k ɪ',
#  'god_nno': 'ɡ uː',
#  'gold_nno': 'ɡ ɔ lː',
#  'googla_nno': 'ɡ ʉː ɡ l a',
#  'gote_nno': '² ɡ oː t ə',
#  'gran_nno': 'ɡ r ɑː n',
#  'granmeis_nno': 'ɡ r aː n m ɛ i s',
#  'grapset_nno': 'ɡ r ɑ p s ə',
#  'grateng_nno': 'ɡ ɾ ɑ t ɛ ŋ',
#  'grava_nno': '² ɡ r ɑː ʋ ɑ',
#  'gravi_nno': 'ɡ r ɑː ʋ ɪ',
#  'gravla_nno': 'ɡ r aː ʋ l aː',
#  'gravleggja_nno': 'ɡ r aː ʋ l ɛ ʝ a',
#  'grebbe_nno': '² ɡ r ɛ bː ə',
#  'grebben_nno': 'ɡ r ɛ bː ə n',
#  'grei_nno': 'ɡ r æ ɪ',
#  'greia_nno': '² ɡ r æ ɪ̯ ɑ',
#  'greie_nno': '² ɡ r æ ɪ̯ ə',
#  'grein_nno': 'ɡ r æ ɪ̯ n',
#  'grend_nno': 'ɡ r ɛ nː',
#  'grim_nno': 'ɡ r ɪ mː',
#  'grima_nno': '² ɡ r iː m ɑ',
#  'grime_nno': '² ɡ r iː m ə',
#  'grina_nno': 'ɡ r iː n ɑ',
#  'grind_nno': 'ɡ r ɪ nː',
#  'griner_nno': 'ɡ r iː n ə r',
#  'grinet_nno': 'ɡ r iː n ə',
#  'grini_nno': 'ɡ r iː n ɪ',
#  'gripa_nno': '² ɡ r iː p ɑ',
#  'gripe_nno': '² ɡ r iː p ə',
#  'gro_nno': 'ɡ r uː',
#  'grov_nno': 'ɡ r uː ʋ',
#  'grunn_nno': 'ɡ r ʉ nː',
#  'grunnleggja_nno': '² ɡ r ʉ nː l ɛ jː ɑ',
#  'grunnleggjande_nno': 'ɡ r ʉ n l ɛ ʝ a n d ə',
#  'grunnlov_nno': 'ɡ r ʉ n l ɔ ʋ',
#  'gruppe_nno': '² ɡ r ʉ pː ə',
#  'grut_nno': 'ɡ r ʉː t',
#  'gruvedrift_nno': 'ɡ ɾ ʉʷː ʋ ə d ɾ ɪ f t',
#  'gråbein_nno': 'ɡ ɾ oː b æ ɪ̯ n',
#  'gråt_nno': 'ɡ r oː t',
#  'gråta_nno': '² ɡ r oː t ɑ',
#  'grøft_nno': 'ɡ r œ f t',
#  'grøn_nno': 'ɡ r øː n',
#  'gudskjelov_nno': 'ɡ ʉ t ʃ ə l ɔː ʋ',
#  'gullalder_nno': 'ɡ ʉ l a l d ɛ r',
#  'guvernør_nno': 'ɡ ʉ ʋ ɛ r n øː r',
#  'gyger_nno': 'j yː ɡ ɛ r',
#  'gås_nno': 'ɡ oː s',
#  'gåte_nno': '² ɡ oː t ə',
#  'gørret_nno': 'ɡ œ r r ə',
#  'ha_nno': 'h ɑː',
#  'haga_nno': '² h ɑː ɡ ɑ',
#  'hagje_nno': '² h ɑː j ə',
#  'hagjen_nno': '² h ɑː j ə n',
#  'hallik_nno': 'h ɑ l l ɪ k',
#  'halvøy_nno': 'h ɑ lː œ j',
#  'hamar_nno': 'h ɑ̂ː m ɑ rˠ',
#  'hamarhai_nno': 'h aː m a r h a i',
#  'han_nno': 'h ɑ nː',
#  'hand_nno': 'h ɑ nː',
#  'handlevogn_nno': 'h ɑ̂ n l ə ʋ ɔ ŋ n',
#  'hann_nno': 'h a n',
#  'hans_nno': 'h ɑ n s',
#  'har_nno': 'h ɑː r',
#  'hard_nno': 'h ɑː ɽ',
#  'hardare_nno': '² h ɑː r ɑ r ə',
#  'hardast_nno': 'h ɑː r ɑ s t',
#  'hardaste_nno': '² h ɑː r ɑ s t ə',
#  'harde_nno': '² h ɑː r ə',
#  'hardt_nno': 'h ɑ r t',
#  'hare_nno': '² h ɑː r ə',
#  'hatefull_nno': 'h aː t ə f ʉ l',
#  'hauen_nno': 'h œ ʉ̯ ə n',
#  'haug_nno': 'h œ ʉ̯ ɡ',
#  'haukjen_nno': 'h œ ʉ̯ ç ə n',
#  'haure_nno': '² h œ ʉ̯ r ə',
#  'hav_nno': 'h ɑː ʋ',
#  'havfru_nno': 'h aː ʋ f ɾ ʉʷː',
#  'heie_nno': 'h æ̂ ɪ̯ː ə',
#  'heil_nno': 'h æ ɪ l',
#  'heilag_nno': 'h ɛ i l aː ɡ',
#  'heim_nno': 'h ɛ ɪ m',
#  'heima_nno': '² h æ ɪ̯ m ɑ',
#  'heimanfrå_nno': 'h ɛ i m a n f r ɒ',
#  'heime_nno': '² h æ ɪ̯ m ə',
#  'heimebrent_nno': 'h ɛ i m ə b r ɛ n t',
#  'heimland_nno': 'h ɛ i m l a n',
#  'heimsøkja_nno': 'h ɛ i m s øː ç a',
#  'heimsøkt_nno': 'h ɛ i m s øː k t',
#  'heita_nno': '² h æ ɪ t ɑ',
#  'hekka_nno': 'h ɛ k a',
#  'heller_nno': '² h ɛ lː ɛ r',
#  'helsig_nno': '² h ɛ l s ɪ',
#  'helst_nno': 'h ɛ l s t',
#  'helsug_nno': '² h ɛ l s ʉ ɡ',
#  'heme_nno': '² h eː m ə',
#  'hemmeleg_nno': 'h ɛ m ə l eː ɡ',
#  'hemn_nno': 'h ɛ m n',
#  'hems_nno': 'h ɛ m s',
#  'henda_nno': '² h ɛ n n ɑ',
#  'hending_nno': 'h ɛ n d i ŋ ɡ',
#  'hendt_nno': 'h ɛ n t',
#  'hengslet_nno': '² h ɛ ŋ s l ɛ t',
#  'hengsli_nno': 'h ɛ ŋ s l ɪ',
#  'henne_nno': 'h ɛ n ə',
#  'hent_nno': 'h ɛ n t',
#  'her_nno': 'h æː r',
#  'herad_nno': '² h ɛː r ɑ',
#  'herd_nno': 'h æː r',
#  'herleg_nno': 'h ɛː r l eː ɡ',
#  'herme_nno': '² h æ ɾ m ə',
#  'herre_nno': '² h æ r r ə',
#  'herregud_nno': 'h ɛ r ə ɡ ʉː d',
#  'hes_nno': 'h eː s',
#  'hest_nno': 'h ɛ s t',
#  'hettitt_nno': 'h eː t i t',
#  'hettittisk_nno': 'h eː t i t i s k',
#  'hevda_nno': '² h ɛ ʋ d ɑ',
#  'hi_nno': 'h iː',
#  'hidsjab_nno': 'h ɪ d ʂ ɑ b',
#  'hijab_nno': 'h ɪ d ʂ ɑ b',
#  'him_nno': 'h iː m',
#  'hima_nno': '² h iː m ɑ',
#  'hin_nno': 'h ɪ nː',
#  'hindra_nno': '² h ɪ n d r ɑ',
#  'hindu_nno': 'h ɪ n d ʉ',
#  'hinduisme_nno': 'h ɪ n d ʉ ɪ s m ə',
#  'hine_nno': '² h iː n ə',
#  'historikar_nno': 'h i s t u r i k a r',
#  'hit_nno': 'h iː t',
#  'hitt_nno': 'h ɪ tː',
#  'hjarte_nno': '² j ɑː r t ə',
#  'hjelpa_nno': '² j ɛ l p ɑ',
#  'hjort_nno': 'j ʊ r t',
#  'ho_nno': 'h uː',
#  "ho'en_nno": 'h uː ə n',
#  'hoe_nno': 'h uː ə',
#  'hogga_nno': '² h ɔ ɡː ɑ',
#  'hokke_nno': 'h ɔ k k ə',
#  'hokken_nno': '² h ɔ k k ə n',
#  'hol_nno': 'h uː l',
#  'holete_nno': '² h oː l ɛ t ə',
#  'homma_nno': '² h ɔ m m ɑ',
#  'homofili_nno': 'h ʊ m ʊ f ɪ l iː',
#  'hord_nno': 'h ɔː r',
#  'hordaland_nno': 'h ɔː r ɑ l ɑ nː',
#  'horet_nno': '² h uː r ə t',
#  'horngjel_nno': 'h ɔ r n j eː l',
#  'hosten_nno': '² h ʊ s t n̩',
#  'hov_nno': 'h uː ʋ',
#  'hove_nno': '² h o ʋ ə',
#  'hovud_nno': '² h ɔˑ ʋ ʉ',
#  'hovuddel_nno': 'h uʷː ʋ ʉ d d eː l',
#  'hovudinngang_nno': 'h uʷː ʋ ʉ d ɪ ŋ ɡ ɑ ŋ',
#  'hue_nno': '² h ʉː ə',
#  'hug_nno': 'h ʉː ɡ',
#  'hulder_nno': 'h ʉ l d ɛ r',
#  'hummar_nno': 'h ʊ m a r',
#  'humpete_nno': '² h ʊ m p ɛ t ə',
#  'hund_nno': 'h ʊ nː',
#  'hundemat_nno': 'h ʉʷ n n ə m aː t',
#  'hundrad_nno': '² h ʊ n d rˠ ɑ',
#  'hundrevis_nno': 'h ʊ n d r ə v iː s',
#  'hundreår_nno': '² h ʊ n d r ə oː r',
#  'huning_nno': '² h uː n i ŋ ɡ',
#  'husfred_nno': 'h ʉː s f r eː',
#  'huttemegtu_nno': 'h ʉ t əː m eː ɡ t ʉː',
#  'huttetu_nno': 'h ʉ t əː t ʉː',
#  'huve_nno': '² h ʉː ʋ ə',
#  'hygga_nno': '² h ʏ ɡ ɡ ɑ',
#  'hygge_nno': '² h ʏ ɡ ɡ ɑ',
#  'hyggjeleg_nno': 'h y ʝ e l eː ɡ',
#  'hyse_nno': '² h yː s ə',
#  'hå_nno': 'h oː',
#  'håa_nno': '² h oː ɑ',
#  'håe_nno': '² h oː ə',
#  'håen_nno': 'h oː ə n',
#  'håg_nno': 'h ɔː ɡ',
#  'håpa_nno': 'h ɒː p a',
#  'hår_nno': 'h oː r',
#  'hått_nno': 'h ɔ tː',
#  'hæl_nno': 'h æː ɽ',
#  'hóv_nno': 'h uː ʋ',
#  'hø_nno': 'h øː',
#  'høg_nno': 'h øː ɡ',
#  'høge_nno': '² h øː ɡ ə',
#  'høgre_nno': '² h œ ɡ r ə',
#  'høi_nno': 'h øː ɪ',
#  'høyrast_nno': 'h ø y r a s t',
#  'høyre_nno': '² h œ ʏ̯ r ə',
#  'i_nno': 'iː',
#  'iallfall_nno': 'j a l f a l',
#  'id_nno': 'ɪ dː',
#  'ida_nno': '² iː d ɑ',
#  'ide_nno': 'ɪ d eː',
#  'idrett_nno': 'iː d r ɛ t',
#  'ikkje_nno': '² ɪ çː ə',
#  'image_nno': 'ɪ m ɪ d ʂ',
#  'imperium_nno': 'i m p eː r i ʉ m',
#  'imponera_nno': 'i m p uː n eː r a',
#  'indianar_nno': 'i n d i aː n aː r',
#  'industriland_nno': 'ɪ n d ʉʷ s t ɾ iː l ɑ n',
#  'ingen_nno': '² ɪ ŋː ɛ n',
#  'ingenting_nno': '² ɪ ŋː ɛ n t ɪ ŋ',
#  'inkje_nno': '² ɪ ɲ c͡ç ə',
#  'innanfor_nno': '² ɪ nː ɑ n f ɔ r',
#  'innavl_nno': 'i n a ʋ l',
#  'innbrot_nno': 'i n b r ɔː t',
#  'innehalda_nno': 'i n ə h a l d a',
#  'innom_nno': 'i n u m',
#  'innsjå_nno': 'i n ʃ ɒː',
#  'innvandra_nno': 'i n ʋ a n d r a',
#  'innvandrar_nno': 'i n ʋ a n d r aː r',
#  'innvandring_nno': 'i n ʋ a n d r i ŋ ɡ',
#  'innverknad_nno': 'i n ʋ ɛ r k n a',
#  'inspirerande_nno': 'i n s p i r eː r aː n ə',
#  'internasjonal_nno': 'i n t ɛ r n aː ʃ uː n aː l',
#  'intim_nno': 'ɪ n t iː m',
#  'invadera_nno': 'i n ʋ aː d eː r a',
#  'invasjon_nno': 'i n ʋ a ʃ uː n',
#  'invitera_nno': 'i n ʋ iː t eː r a',
#  'is_nno': 'iː s',
#  'isfjell_nno': 'iː s f j ɛ l',
#  'islam_nno': 'ɪ ʂ l ɑː m',
#  'isme_nno': '² ɪ s m ə',
#  'jakt_nno': 'j a k t',
#  'jakta_nno': 'j a k t a',
#  'jaktar_nno': 'j a k t aː r',
#  'jarn_nno': 'j ɑ r n',
#  'jase_nno': '² j ɑː s ə',
#  'jasen_nno': '² j ɑː s ə n',
#  'jest_nno': 'j ɛ s t',
#  'jester_nno': 'j ɛ s t ə r',
#  'joletid_nno': 'j uʷː l ə t iː d',
#  'joletre_nno': 'j uː l əː t r e',
#  'jord_nno': 'j uː ʁ',
#  'jorda_nno': 'j uː r ɑ',
#  'jordbær_nno': 'j u ɻ b æː r',
#  'jorde_nno': '² j uː ɽ ə',
#  'jordeple_nno': '² j ɔ r p l ə',
#  'journalist_nno': 'ʃ u r n a l i s t',
#  'jovial_nno': 'j ʊ ʋ ɪ aː l',
#  'juletre_nno': 'j ʉː l əː t r e',
#  'jungel_nno': 'j ʊ ŋ ɡ ə l',
#  'juv_nno': 'j ʉː ʋ',
#  'jævel_nno': '² j æː ʋ ə l',
#  'jøde_nno': 'j øː d ə',
#  'jødedom_nno': 'j øː d ə d ɔː m',
#  'jødisk_nno': 'j øː d i s k',
#  'kabylsk_nno': 'k ɑ b yː l s k',
#  'kaffi_nno': 'k a f i',
#  'kalde_nno': '² k ɑ lː ə',
#  'kalla_nno': '² k ɑ lː ɑ',
#  'kameleon_nno': 'k ɑ m ə l ə uː n',
#  'kandidatur_nno': 'k ɑ n d ɪ d ɑ t ʉː r',
#  'kapre_nno': '² k ɑː p r ə',
#  'kar_nno': 'k ɑː r',
#  'karboksylsyre_nno': 'k ɑ ɾ b ʊ k s yʷː l s yʷː ɾ ə',
#  'karsk_nno': 'k a r s k',
#  'katastrofal_nno': 'k a t a s t r u f aː l',
#  'katastrofalt_nno': 'k a t a s t r u f aː l t',
#  'katt_nno': 'k ɑ tː',
#  'kause_nno': '² k œ ʉ̯ s ə',
#  'kausen_nno': '² k œ ʉ̯ s ə n',
#  'kebab_nno': 'k eː b ɑː b',
#  'keip_nno': 'ç æ ɪ̯ p',
#  'keipa_nno': '² ç æ ɪ̯ p ɑ',
#  'keipe_nno': '² ç æ ɪ̯ p ə',
#  'keipen_nno': 'ç æ ɪ̯ p ə n',
#  'keisam_nno': 'ç ɛ iː s aː m',
#  ...}

# %%
len(lemma_dict)
# Out:
# 1882240

# %%
df["PRON"] = df["lemma_lang"].apply(lambda x: lemma_dict.get(x, np.NaN))
# Out:
# /var/folders/bj/qp6k2wl11h5gpn8j4hg0tgf40000gn/T/ipykernel_47369/3220908707.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["PRON"] = df["lemma_lang"].apply(lambda x: lemma_dict.get(x, np.NaN))

# %%
# df.dropna(subset=["PRON"], inplace=True)
# Out:
# /var/folders/bj/qp6k2wl11h5gpn8j4hg0tgf40000gn/T/ipykernel_31562/2895585835.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset=["PRON"], inplace=True)

# %%
df
# Out:
#                      SENSE_LEMMA LANG             SYNSET1          SYNSET2
# 0        tropidoclonion_lineatum   BG  Tropidoclonion#n#1  lined_snake#n#1  \
# 1        tropidoclonion_lineatum   RU  Tropidoclonion#n#1  lined_snake#n#1
# 2        tropidoclonion_lineatum   UK  Tropidoclonion#n#1  lined_snake#n#1
# 3        tropidoclonion_lineatum   GA  Tropidoclonion#n#1  lined_snake#n#1
# 4        tropidoclonion_lineatum   RO  Tropidoclonion#n#1  lined_snake#n#1
# ...                          ...  ...                 ...              ...
# 1981301                   menuil   MS            jack#v#1          pry#v#1
# 1981302                   menuas   MS            jack#v#1          pry#v#1
# 1981303                   menuil   ID            jack#v#1          pry#v#1
# 1981304                   menuas   ID            jack#v#1          pry#v#1
# 1981305               mengungkit   ID            jack#v#1          pry#v#1
#
#                      C1           C2  diff lang C1.lemma  C1.V.Mean.Sum
# 0        tropidoclonion  lined_snake  True   bg      NaN            NaN  \
# 1        tropidoclonion  lined_snake  True   ru      NaN            NaN
# 2        tropidoclonion  lined_snake  True   uk      NaN            NaN
# 3        tropidoclonion  lined_snake  True   ga      NaN            NaN
# 4        tropidoclonion  lined_snake  True   ro      NaN            NaN
# ...                 ...          ...   ...  ...      ...            ...
# 1981301            jack          pry  True   ms      NaN            NaN
# 1981302            jack          pry  True   ms      NaN            NaN
# 1981303            jack          pry  True   id      NaN            NaN
# 1981304            jack          pry  True   id      NaN            NaN
# 1981305            jack          pry  True   id      NaN            NaN
#
#          C1.V.SD.Sum  C1.V.Rat.Sum  C1.A.Mean.Sum  C1.A.SD.Sum  C1.A.Rat.Sum
# 0                NaN           NaN            NaN          NaN           NaN  \
# 1                NaN           NaN            NaN          NaN           NaN
# 2                NaN           NaN            NaN          NaN           NaN
# 3                NaN           NaN            NaN          NaN           NaN
# 4                NaN           NaN            NaN          NaN           NaN
# ...              ...           ...            ...          ...           ...
# 1981301          NaN           NaN            NaN          NaN           NaN
# 1981302          NaN           NaN            NaN          NaN           NaN
# 1981303          NaN           NaN            NaN          NaN           NaN
# 1981304          NaN           NaN            NaN          NaN           NaN
# 1981305          NaN           NaN            NaN          NaN           NaN
#
#          C1.D.Mean.Sum  C1.D.SD.Sum  C1.D.Rat.Sum C2.lemma  C2.V.Mean.Sum
# 0                  NaN          NaN           NaN      NaN            NaN  \
# 1                  NaN          NaN           NaN      NaN            NaN
# 2                  NaN          NaN           NaN      NaN            NaN
# 3                  NaN          NaN           NaN      NaN            NaN
# 4                  NaN          NaN           NaN      NaN            NaN
# ...                ...          ...           ...      ...            ...
# 1981301            NaN          NaN           NaN      pry           3.57
# 1981302            NaN          NaN           NaN      pry           3.57
# 1981303            NaN          NaN           NaN      pry           3.57
# 1981304            NaN          NaN           NaN      pry           3.57
# 1981305            NaN          NaN           NaN      pry           3.57
#
#          C2.V.SD.Sum  C2.V.Rat.Sum  C2.A.Mean.Sum  C2.A.SD.Sum  C2.A.Rat.Sum
# 0                NaN           NaN            NaN          NaN           NaN  \
# 1                NaN           NaN            NaN          NaN           NaN
# 2                NaN           NaN            NaN          NaN           NaN
# 3                NaN           NaN            NaN          NaN           NaN
# 4                NaN           NaN            NaN          NaN           NaN
# ...              ...           ...            ...          ...           ...
# 1981301         1.86          21.0            5.3         2.58          20.0
# 1981302         1.86          21.0            5.3         2.58          20.0
# 1981303         1.86          21.0            5.3         2.58          20.0
# 1981304         1.86          21.0            5.3         2.58          20.0
# 1981305         1.86          21.0            5.3         2.58          20.0
#
#          C2.D.Mean.Sum  C2.D.SD.Sum  C2.D.Rat.Sum LANG_PRON
# 0                  NaN          NaN           NaN       bul  \
# 1                  NaN          NaN           NaN       rus
# 2                  NaN          NaN           NaN       ukr
# 3                  NaN          NaN           NaN       gle
# 4                  NaN          NaN           NaN       ron
# ...                ...          ...           ...       ...
# 1981301           4.85         2.25          20.0       msa
# 1981302           4.85         2.25          20.0       msa
# 1981303           4.85         2.25          20.0       ind
# 1981304           4.85         2.25          20.0       ind
# 1981305           4.85         2.25          20.0       ind
#
#                              LANG_NAME  LEN                   lemma_lang PRON
# 0                            Bulgarian  3.0  tropidoclonion_lineatum_bul  NaN
# 1                              Russian  3.0  tropidoclonion_lineatum_rus  NaN
# 2                            Ukrainian  3.0  tropidoclonion_lineatum_ukr  NaN
# 3                                Irish  3.0  tropidoclonion_lineatum_gle  NaN
# 4        Romanian; Moldavian; Moldovan  3.0  tropidoclonion_lineatum_ron  NaN
# ...                                ...  ...                          ...  ...
# 1981301          Malay (macrolanguage)  3.0                   menuil_msa  NaN
# 1981302          Malay (macrolanguage)  3.0                   menuas_msa  NaN
# 1981303                     Indonesian  3.0                   menuil_ind  NaN
# 1981304                     Indonesian  3.0                   menuas_ind  NaN
# 1981305                     Indonesian  3.0               mengungkit_ind  NaN
#
# [1980472 rows x 33 columns]

# %%
from collections import defaultdict

# %%
dfp = df.dropna(subset=["PRON"]).drop_duplicates(subset=["lemma_lang", "PRON"])

# %%
dfp
# Out:
#           SENSE_LEMMA LANG        SYNSET1         SYNSET2         C1
# 41       protubérance   FR      gnarl#v#1       tuber#n#1      gnarl  \
# 44            enflure   FR   swelling#n#1       tuber#n#1   swelling
# 48                कंद   HI       bulb#n#1     condyle#n#1       bulb
# 55                ubi   MS       bulb#n#1       tuber#n#1       bulb
# 58                 củ   VI      tuber#n#1  tuberosity#n#1      tuber
# ...               ...  ...            ...             ...        ...
# 1981281    interagire   IT   interact#v#1   intervene#v#1   interact
# 1981286     interfere   EN  interfere#v#1   intervene#v#1  interfere
# 1981296     intessere   IT        tat#v#1       weave#v#1        tat
# 1981298        บุกรุก   TH    intrude#v#1    trespass#v#1    intrude
# 1981299      jodioida   FI   iodinate#v#1      iodize#v#1   iodinate
#
#                  C2  diff lang   C1.lemma  C1.V.Mean.Sum  C1.V.SD.Sum
# 41            tuber  True   fr        NaN            NaN          NaN  \
# 44            tuber  True   fr        NaN            NaN          NaN
# 48          condyle  True   hi       bulb           5.86         1.68
# 55            tuber  True   ms       bulb           5.86         1.68
# 58       tuberosity  True   vi        NaN            NaN          NaN
# ...             ...   ...  ...        ...            ...          ...
# 1981281   intervene  True   it   interact           6.00         1.41
# 1981286   intervene  True   en  interfere           3.94         1.86
# 1981296       weave  True   it        NaN            NaN          NaN
# 1981298    trespass  True   th    intrude           3.10         1.61
# 1981299      iodize  True   fi        NaN            NaN          NaN
#
#          C1.V.Rat.Sum  C1.A.Mean.Sum  C1.A.SD.Sum  C1.A.Rat.Sum
# 41                NaN            NaN          NaN           NaN  \
# 44                NaN            NaN          NaN           NaN
# 48               21.0           3.26         2.40          19.0
# 55               21.0           3.26         2.40          19.0
# 58                NaN            NaN          NaN           NaN
# ...               ...            ...          ...           ...
# 1981281          20.0           3.78         2.07          23.0
# 1981286          18.0           4.33         2.78          21.0
# 1981296           NaN            NaN          NaN           NaN
# 1981298          21.0           5.20         1.99          20.0
# 1981299           NaN            NaN          NaN           NaN
#
#          C1.D.Mean.Sum  C1.D.SD.Sum  C1.D.Rat.Sum   C2.lemma  C2.V.Mean.Sum
# 41                 NaN          NaN           NaN        NaN            NaN  \
# 44                 NaN          NaN           NaN        NaN            NaN
# 48                4.82         2.48          22.0        NaN            NaN
# 55                4.82         2.48          22.0        NaN            NaN
# 58                 NaN          NaN           NaN        NaN            NaN
# ...                ...          ...           ...        ...            ...
# 1981281           5.46         2.52          28.0  intervene           5.21
# 1981286           4.71         2.24          28.0  intervene           5.21
# 1981296            NaN          NaN           NaN      weave           5.41
# 1981298           3.92         2.22          25.0   trespass           3.27
# 1981299            NaN          NaN           NaN        NaN            NaN
#
#          C2.V.SD.Sum  C2.V.Rat.Sum  C2.A.Mean.Sum  C2.A.SD.Sum  C2.A.Rat.Sum
# 41               NaN           NaN            NaN          NaN           NaN  \
# 44               NaN           NaN            NaN          NaN           NaN
# 48               NaN           NaN            NaN          NaN           NaN
# 55               NaN           NaN            NaN          NaN           NaN
# 58               NaN           NaN            NaN          NaN           NaN
# ...              ...           ...            ...          ...           ...
# 1981281         1.40          19.0           4.48         2.48          23.0
# 1981286         1.40          19.0           4.48         2.48          23.0
# 1981296         1.22          22.0           3.10         2.05          21.0
# 1981298         1.61          22.0           4.79         2.30          19.0
# 1981299          NaN           NaN            NaN          NaN           NaN
#
#          C2.D.Mean.Sum  C2.D.SD.Sum  C2.D.Rat.Sum LANG_PRON
# 41                 NaN          NaN           NaN       fra  \
# 44                 NaN          NaN           NaN       fra
# 48                 NaN          NaN           NaN       hin
# 55                 NaN          NaN           NaN       msa
# 58                 NaN          NaN           NaN       vie
# ...                ...          ...           ...       ...
# 1981281           5.82         2.02          28.0       ita
# 1981286           5.82         2.02          28.0       eng
# 1981296           6.36         1.89          22.0       ita
# 1981298           5.00         2.19          21.0       tha
# 1981299            NaN          NaN           NaN       fin
#
#                      LANG_NAME  LEN        lemma_lang                   PRON
# 41                      French  3.0  protubérance_fra   p ʁ ɔ t y b e ʁ ɑ̃ s
# 44                      French  3.0       enflure_fra             ɑ̃ f l y ʁ
# 48                       Hindi  3.0           कंद_hin             k ə̃ n̪ d̪
# 55       Malay (macrolanguage)  3.0           ubi_msa                  u b i
# 58                  Vietnamese  3.0            củ_vie                 k u ˧˩
# ...                        ...  ...               ...                    ...
# 1981281                Italian  3.0    interagire_ita  i n t e r a d͡ʒ i r e
# 1981286                English  3.0     interfere_eng        ɪ n t ə f ɪ ə ɹ
# 1981296                Italian  3.0     intessere_ita      i n t ɛ s s e r e
# 1981298                   Thai  3.0        บุกรุก_tha    b u k̚ ˨˩ r u k̚ ˦˥
# 1981299                Finnish  3.0      jodioida_fin   j o̞ d i o̞ i̯ d ɑ ʔ
#
# [139698 rows x 33 columns]

# %%
dfp.to_csv("../data/finals/colex_wn_phon_dedup.csv", index=False)

# %%
len(dfp), len(dfp["LANG_PRON"].value_counts().to_dict())
# Out:
# (139698, 150)

# %%
lang2phones = defaultdict(list)
for lang, pron in zip(dfp["LANG_PRON"], dfp["PRON"]):
    lang2phones[lang]+= pron.split()

# %%
lang2phon = {}

for lang, phons in lang2phones.items():
    lang2phon[lang]= list(set(phons))

# %%
lang2phon["lit"]
# Out:
# ['s̪ʲ',
#  'ɪ̯̌ː',
#  'ʒ͡ʲ',
#  'ʊ',
#  'i͡ə',
#  'âˑ',
#  'ä̂ː',
#  'ɒ͜úˑ',
#  'ɛ̂ˑ',
#  't̪',
#  's',
#  'ə',
#  'u͡ə',
#  'k',
#  'û',
#  'ŋ',
#  'd̪',
#  'd',
#  'ʃ',
#  'ɐ͡ɪ',
#  'ɡ',
#  'ŋ́',
#  'ǐː',
#  'äː',
#  'ʊ̯ˑ',
#  'à',
#  'æ̌ː',
#  'ʋ',
#  'z',
#  'ǒː',
#  'ə̯',
#  'm',
#  'æ̌ˑ',
#  'ɣʲ',
#  'ɪ̯ˑ',
#  'xʲ',
#  'ŋʲ',
#  'ɪ̂',
#  'ɫ',
#  'ɪ̌͡ə',
#  'ʒ',
#  'n',
#  'ʂ',
#  'ɾ',
#  'z̪',
#  'i̯',
#  'îː',
#  'nʲ',
#  'sʲ',
#  'tʲ',
#  'eː',
#  'n̪ʲ',
#  'j',
#  'rː',
#  'ɐ',
#  'ɪ̯',
#  'fʲ',
#  'e',
#  'ôː',
#  'r',
#  'd̪ʲ',
#  'ɐ͡r',
#  'f',
#  'ɪ͡ə',
#  'jː',
#  'ɔ',
#  'oː',
#  'ɛ̂',
#  'bʲ',
#  'î',
#  'êː',
#  'ʑ',
#  'iː',
#  'aː',
#  'v',
#  'ʃʲ',
#  'vʲ',
#  'ǔː',
#  's̪',
#  'ɕ',
#  'äˑ',
#  'l',
#  'o',
#  'ɪ́',
#  'ěː',
#  'b',
#  'u',
#  'uː',
#  'æ',
#  'ɒ',
#  'ä̌ː',
#  'ʋʲ',
#  'ɪ',
#  'ɛː',
#  'kʲ',
#  'lʲ',
#  'n̪',
#  't͡ʃʲ',
#  'â͡l',
#  'mʲ',
#  'uˑ',
#  'ʒʲ',
#  'ɡʲ',
#  'ɪˑ',
#  'rʲ',
#  'ɛ',
#  'dʲ',
#  'ä̂ˑ',
#  'ǎː',
#  'd͡ʒ',
#  'zʲ',
#  'ʊ̯',
#  'i',
#  'ɾʲ',
#  'p',
#  'æː',
#  'ɪ͡r',
#  'ä̂',
#  't',
#  'ʐ',
#  'ûː',
#  'a',
#  'pʲ',
#  't̪ʲ',
#  't͡sʲ',
#  'ɑː']

# %%
lang2stats= {}
for lang, phons in lang2phon.items():
    lang2stats[lang]= len(phons)

# %%
lang2stats
# Out:
# {'fra': 74,
#  'hin': 83,
#  'msa': 66,
#  'vie': 49,
#  'pol': 37,
#  'por': 87,
#  'ron': 63,
#  'jpn': 78,
#  'swe': 117,
#  'isl': 75,
#  'ces': 49,
#  'fin': 66,
#  'spa': 54,
#  'rus': 88,
#  'nld': 78,
#  'slk': 60,
#  'ukr': 68,
#  'hbs': 63,
#  'deu': 96,
#  'bul': 64,
#  'tha': 50,
#  'gle': 112,
#  'eng': 75,
#  'cmn': 74,
#  'ita': 32,
#  'heb': 63,
#  'slv': 54,
#  'lit': 126,
#  'epo': 28,
#  'tur': 111,
#  'fas': 83,
#  'tam': 48,
#  'kat': 34,
#  'hun': 69,
#  'tgl': 42,
#  'kor': 63,
#  'hye': 40,
#  'bak': 49,
#  'dan': 119,
#  'ind': 59,
#  'glg': 55,
#  'got': 25,
#  'eus': 32,
#  'mkd': 39,
#  'ara': 53,
#  'bel': 41,
#  'aze': 51,
#  'sqi': 68,
#  'nor': 66,
#  'cym': 49,
#  'ell': 44,
#  'mya': 62,
#  'haw': 18,
#  'mlt': 50,
#  'lav': 74,
#  'afr': 57,
#  'glv': 20,
#  'est': 61,
#  'grc': 53,
#  'khm': 47,
#  'dsb': 34,
#  'scn': 34,
#  'ido': 29,
#  'urd': 41,
#  'ltz': 48,
#  'kmr': 27,
#  'kik': 6,
#  'mon': 61,
#  'gla': 69,
#  'nno': 68,
#  'ben': 49,
#  'ast': 36,
#  'bre': 51,
#  'hau': 40,
#  'asm': 23,
#  'fao': 58,
#  'kaz': 45,
#  'sga': 10,
#  'khb': 13,
#  'oci': 32,
#  'vol': 25,
#  'san': 46,
#  'mal': 37,
#  'yor': 14,
#  'che': 13,
#  'nep': 29,
#  'nap': 20,
#  'pms': 14,
#  'nav': 43,
#  'amh': 18,
#  'kir': 23,
#  'enm': 29,
#  'nya': 19,
#  'lao': 42,
#  'cos': 9,
#  'fry': 36,
#  'ang': 33,
#  'tel': 40,
#  'srn': 8,
#  'tuk': 6,
#  'ina': 21,
#  'lim': 4,
#  'xho': 32,
#  'zul': 46,
#  'pdc': 9,
#  'yid': 24,
#  'sce': 7,
#  'mar': 24,
#  'zha': 27,
#  'kal': 4,
#  'pus': 9,
#  'ori': 14,
#  'tgk': 22,
#  'sme': 31,
#  'srd': 9,
#  'sco': 24,
#  'bod': 23,
#  'dlm': 7,
#  'dzo': 5,
#  'krl': 4,
#  'tyv': 22,
#  'lmo': 6,
#  'kas': 5,
#  'bcl': 3,
#  'pan': 13,
#  'nci': 10,
#  'ewe': 16,
#  'ilo': 6,
#  'xal': 6,
#  'izh': 4,
#  'fro': 8,
#  'kbd': 11,
#  'sah': 12,
#  'shn': 5,
#  'mlg': 10,
#  'cor': 21,
#  'new': 6,
#  'stq': 6,
#  'liv': 1,
#  'frr': 10,
#  'ceb': 5,
#  'cop': 7,
#  'mic': 8,
#  'ton': 3,
#  'mnc': 8,
#  'abk': 3,
#  'mdf': 2,
#  'ady': 5,
#  'ltg': 8,
#  'kan': 5}

# %%
np.min(list(lang2stats.values())), # liv,
# Out:
# 1

# %%
np.max(list(lang2stats.values())), # lit
# Out:
# (126,)

# %%
np.median(list(lang2stats.values())), # liv,
# Out:
# (32.5,)

# %%
df.to_csv("../data/finals/colex_wn_pron_aff.csv", index=False)

# %%
df[df["SENSE_LEMMA"]=="gefängnis"]
# Out:
#         SENSE_LEMMA LANG   SYNSET1     SYNSET2    C1      C2  diff lang
# 1350906   gefängnis   DE  jail#n#1  prison#n#1  jail  prison  True   de  \
#
#         C1.lemma  C1.V.Mean.Sum  C1.V.SD.Sum  C1.V.Rat.Sum  C1.A.Mean.Sum
# 1350906     jail           1.91         1.44         870.0           4.47  \
#
#          C1.A.SD.Sum  C1.A.Rat.Sum  C1.D.Mean.Sum  C1.D.SD.Sum  C1.D.Rat.Sum
# 1350906          2.5          38.0           3.91         2.91          23.0  \
#
#         C2.lemma  C2.V.Mean.Sum  C2.V.SD.Sum  C2.V.Rat.Sum  C2.A.Mean.Sum
# 1350906   prison           1.94         1.55          18.0            5.1  \
#
#          C2.A.SD.Sum  C2.A.Rat.Sum  C2.D.Mean.Sum  C2.D.SD.Sum  C2.D.Rat.Sum
# 1350906         2.34          21.0           3.54         2.65          52.0  \
#
#         LANG_PRON LANG_NAME  LEN     lemma_lang             PRON
# 1350906       deu    German  3.0  gefängnis_deu  ɡ ə f ɛ ŋ n ɪ s

# %%
valdict1 = dict()
for lemma, v_mean, v_sd, a_mean, a_sd, d_mean, d_sd in zip(df["C1.lemma"], df["C1.V.Mean.Sum"], df["C1.V.SD.Sum"], 
                                                           df["C1.A.Mean.Sum"], df["C1.A.SD.Sum"], df["C1.D.Mean.Sum"], df["C1.D.SD.Sum"]):
    valdict1[lemma] = (v_mean, v_sd, a_mean, a_sd, d_mean, d_sd)

# %%
valdict2 = dict()
for lemma, v_mean, v_sd, a_mean, a_sd, d_mean, d_sd in zip(df["C2.lemma"], df["C2.V.Mean.Sum"], df["C2.V.SD.Sum"], 
                                                           df["C2.A.Mean.Sum"], df["C2.A.SD.Sum"], df["C2.D.Mean.Sum"], df["C2.D.SD.Sum"]):
    valdict2[lemma] = (v_mean, v_sd, a_mean, a_sd, d_mean, d_sd)

# %%
len(valdict1), len(valdict2)
# Out:
# (8277, 8566)

# %%
valdict1.update(valdict2)

# %%
len(valdict1)
# Out:
# 9552

# %%
valdict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[177], line 1
# ----> 1 valdict
#
# NameError: name 'valdict' is not defined

# %%
valdict1["gefängnis"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[176], line 1
# ----> 1 valdict1["gefängnis"]
#
# KeyError: 'gefängnis'

# %%
lemmas,langs, prons, vmeans,vsds, ameans, asds, dmeans, dsds  = [],[],[],[],[],[],[],[],[]
for x, group in df.groupby(["SENSE_LEMMA", "LANG_PRON", "PRON"]):
    lemmas.append(x[0])
    langs.append(x[1])
    prons.append(x[2])
    
    concepts = list(set(group["C1"].tolist()+group["C2"].tolist()))
    
    vmeans_ls, vsds_ls, ameans_ls, asds_ls, dmeans_ls, dsds_ls  = [],[],[],[],[],[]
    for concept in concepts:
        vmean, vsd, amen, asd, dmean, dsd = valdict1[concept]
        vmeans_ls.append(vmean)
        vsds_ls.append(vsd)
        ameans_ls.append(amen)
        asds_ls.append(asd)
        dmeans_ls.append(dmean)
        dsds_ls.append(dsd)
        
    vmeans.append(np.mean(vmeans_ls))
    vsds.append(np.mean(vsds_ls))
    ameans.append(np.mean(ameans_ls))
    asds.append(np.mean(asds_ls))
    dmeans.append(np.mean(dmeans_ls))
    dsds.append(np.mean(dsds_ls))

# %%
phonedf = pd.DataFrame.from_dict({"SENSE_LEMMA": lemmas, "LANG_PRON":langs, "PRON":prons, "V.Mean.Sum":vmeans, "V.SD.Sum": vsds, "A.Mean.Sum": ameans, "A.SD.Sum":asds, 
                                 "D.Mean.Sum":dmeans, "D.SD.Sum":dsds })

# %%
phonedf
# Out:
#        SENSE_LEMMA LANG_PRON                   PRON  V.Mean.Sum  V.SD.Sum  \
# 0                a       hun                     ɒː    5.040000  1.483333
# 1                a       ita                      a    4.340000  1.820000
# 2            aaien       nld              aː i̯ ə n    6.833333  1.446667
# 3         aaltoilu       fin      ɑː l t̪ o̞ i̯ l u    4.575000  1.745000
# 4       aamuhämärä       fin     ɑː m u h æ m æ r æ    6.490000  2.070000
# ...            ...       ...                    ...         ...       ...
# 58943       𐌿𐍂𐍂𐌿𐌽𐍃       got            u r r u n s    5.395000  1.750000
# 58944       𐍃𐌺𐌴𐌹𐌼𐌰       got             s k iː m a    4.935000  1.700000
# 58945      𐍅𐌰𐌹𐌽𐌰𐌷𐍃       got           w ɛː n a h s    2.220000  1.485000
# 58946       𐍅𐍉𐌸𐌴𐌹𐍃       got            w oː θ iː s    7.505000  1.445000
# 58947  𐍆𐌿𐌻𐌻𐌰𐍆𐌰𐌷𐌾𐌰𐌽       got  f u l l a f a h j a n    6.895000  1.825000
#
#        A.Mean.Sum  A.SD.Sum  D.Mean.Sum  D.SD.Sum
# 0        3.948333  2.381667    5.128333  2.176667
# 1        3.623333  2.483333    5.096667  1.993333
# 2        4.236667  2.590000    6.256667  1.973333
# 3        4.280000  2.145000    5.170000  2.080000
# 4        3.650000  2.275000    4.890000  2.445000
# ...           ...       ...         ...       ...
# 58943    3.375000  2.535000    5.035000  2.615000
# 58944    4.165000  2.195000    5.550000  2.160000
# 58945    5.080000  2.720000    3.785000  2.170000
# 58946    3.525000  2.720000    6.410000  1.965000
# 58947    4.350000  2.655000    6.125000  2.265000
#
# [58948 rows x 9 columns]

# %%
phonedf.to_csv("../data/affectiveness/wn_wkb_wikipron.csv", index=False)
